# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import polyline
import uuid

# %%
df = pd.read_csv('../data/activities_small.csv', encoding='utf-8') # read is small dataset

# %%
df.columns.tolist()
# Out:
# [u'id',
#  u'name',
#  u'distance',
#  u'moving_time',
#  u'elapsed_time',
#  u'total_elevation_gain',
#  u'type',
#  u'start_date',
#  u'start_date_local',
#  u'timezone',
#  u'achievement_count',
#  u'kudos_count',
#  u'comment_count',
#  u'athlete_count',
#  u'photo_count',
#  u'total_photo_count',
#  u'trainer',
#  u'commute',
#  u'manual',
#  u'private',
#  u'flagged',
#  u'average_speed',
#  u'max_speed',
#  u'average_watts',
#  u'max_watts',
#  u'weighted_average_watts',
#  u'kilojoules',
#  u'device_watts',
#  u'has_heartrate',
#  u'average_heartrate',
#  u'max_heartrate',
#  u'athlete_id',
#  u'map_id',
#  u'map_summary_polyline',
#  u'start_lat',
#  u'start_lng',
#  u'end_lat',
#  u'end_lng',
#  u'state',
#  u'closest_city']

# %%
df = df[df['commute'] == 0] # drop all where commute = true
df = df[df['state'] == 'Colorado'] # drop all where state != Colorado
df.dropna(subset=['map_summary_polyline'], inplace=True) # drop all where map_summary_polyline is nan
df.reset_index(drop=True, inplace=True)
df.shape
# Out:
# (7164, 40)

# %%
df.head()
# Out:
#           id                                     name  distance  moving_time  \
# 0  467664896               Fat Bike in the snow at GM   12557.8       4111.0
# 1  308543489  05/19/2015 Fruita, CO Horse Thief Bench   15941.8       3448.0
# 2  432799746                               Lunch Ride   77276.3      10158.0
# 3  308543507          05/20/2015 Fruita, CO Edge Loop   53577.9      14160.0
# 4  718012436                  Lunch ride with Spencer   26395.2       4604.0
#
#    elapsed_time  total_elevation_gain  type                 start_date  \
# 0        4193.0                 419.4  Ride  2016-01-10 19:13:47+00:00
# 1        4356.0                 322.0  Ride  2015-05-20 00:41:46+00:00
# 2       15286.0                 962.0  Ride  2015-11-14 19:21:32+00:00
# 3       19563.0                1355.0  Ride  2015-05-20 15:55:46+00:00
# 4        4971.0                 391.7  Ride  2016-09-19 17:04:45+00:00
#
#       start_date_local        timezone     ...       max_heartrate  \
# 0  2016-01-10 12:13:47  America/Denver     ...                 NaN
# 1  2015-05-19 18:41:46  America/Denver     ...               148.0
# 2  2015-11-14 12:21:32  America/Denver     ...                 NaN
# 3  2015-05-20 09:55:46  America/Denver     ...               159.0
# 4  2016-09-19 11:04:45  America/Denver     ...                 NaN
#
#    athlete_id      map_id                               map_summary_polyline  \
# 0     7360660  a467664896  w`gqFnpx`SDzEkDYw@wBApDdBjBGlD~@~@u@pCgJdD_AdM...
# 1      113571  a308543489  scbnFjbgwSQjMzFhGnAzMJdEgBdBWtDpA`G|NnU`AxImAx...
# 2       67365  a432799746  kf`sFhaiaS}KiBsAtFyI`ByeAjyBqBjNeJt@iC_EcGsAcn...
# 3      113571  a308543507  ez|nFrrnvSvRzu@aKhOsw@|FzDxFoKpZlMz_@qBpL}PrCk...
# 4      153343  a718012436  sojsFd_naSs@r@|BsCMgBxMaAzByD~b@{@nAsCKaPhBy@v...
#
#    start_lat  start_lng end_lat end_lng     state closest_city
# 0      39.69    -105.15   39.69 -105.15  Colorado     Lakewood
# 1      39.17    -108.83   39.18 -108.83  Colorado       Fruita
# 2      39.98    -105.24   39.98 -105.24  Colorado      Boulder
# 3      39.31    -108.71   39.31 -108.71  Colorado       Fruita
# 4      40.04    -105.26   40.04 -105.26  Colorado      Boulder
#
# [5 rows x 40 columns]

# %%
lats = df.start_lat.values

# %%
lngs = df.start_lng.values

# %%
from itertools import izip
dsts = []
for (lt, lg) in izip(lats, lngs):
    dsts.append(np.sqrt((lats - lt)**2 + (lngs - lg)**2))

# %%
dsts = np.array(dsts)
il1 = np.tril_indices(dsts.shape[0])
dsts[il1] = -1

# %%
dsts.shape
# Out:
# (7164, 7164)

# %%
dsts[:4, :4]
# Out:
# array([[-1.        ,  3.71655755,  0.30364453,  3.58022346],
#        [-1.        , -1.        ,  3.68024456,  0.18439089],
#        [-1.        , -1.        , -1.        ,  3.53409111],
#        [-1.        , -1.        , -1.        , -1.        ]])

# %%
pairs = np.argwhere((dsts <= 0.01) & (dsts > -1)) # all pairs of indices with distances between start locations shorter than threshold of 0.01

# %%
pairs[:15]
# Out:
# array([[   0,  466],
#        [   0, 1818],
#        [   0, 1873],
#        [   0, 2731],
#        [   0, 2790],
#        [   0, 3904],
#        [   0, 7025],
#        [   1,  216],
#        [   1,  547],
#        [   1, 1152],
#        [   1, 1260],
#        [   1, 1591],
#        [   1, 3346],
#        [   1, 4471],
#        [   1, 5295]])

# %%
def make_indexer(arr): # might not need indexer
    indexer = {}
    for pair in arr:
        if pair[0] in indexer:
            indexer[pair[0]].append(pair[1])
        else:
            indexer[pair[0]] = [pair[1]]
    return indexer
start_clusters = make_indexer(pairs)

# %%
# start_clusters

# %%
poly1 = np.array(polyline.decode(df.ix[0, 'map_summary_polyline'])).flatten()

# %%
poly2 = np.array(polyline.decode(df.ix[2574, 'map_summary_polyline'])).flatten()

# %%
len(poly1)
# Out:
# 170

# %%
len(poly2)
# Out:
# 122

# %%
def polytrim(poly1, poly2):
    diff = len(poly1) - len(poly2)
    rands = np.random.choice(np.arange(0, len(poly1)-2, 2), diff/2, replace=False)
    return np.delete(poly1, np.hstack((rands,rands+1)))

def conditional_dist(poly1, poly2):
    if np.linalg.norm(np.subtract(poly1[-2:], poly2[-2:])) <= 0.01: # if end points are close by a certain threshold
        if len(poly1) > len(poly2):
            poly1 = polytrim(poly1, poly2)
        elif len(poly1) < len(poly2):
            poly2 = polytrim(poly2, poly1)
        return np.linalg.norm(np.subtract(poly1, poly2)) # return distance between polylines

# %%
poly_pair_dsts = []
for idx1, other_idxs in start_clusters.iteritems():
    for idx2 in other_idxs:
        poly1 = np.array(polyline.decode(df.ix[idx1, 'map_summary_polyline'])).flatten()
        poly2 = np.array(polyline.decode(df.ix[idx2, 'map_summary_polyline'])).flatten()
        dist = conditional_dist(poly1, poly2)
        if dist is not None: # if distance between polylines is not None, add to list
            poly_pair_dsts.append(dist)

# %%
len(poly_pair_dsts)
# Out:
# 125390

# %%
import matplotlib.mlab as mlab
x = poly_pair_dsts

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='green', alpha=0.75)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title(r'$\mathrm{Histogram\ of\ activity\ polylines\ that\ are\ close:}\ \mu=100,\ \sigma=15$')
# plt.axis([40, 160, 0, 0.03])
plt.grid(True)

plt.show()

# %%
from scipy import stats

# %%
rslt = stats.describe(poly_pair_dsts)
print "mean: {}".format(rslt.mean), "var: {}".format(rslt.variance)
# Out:
# mean: 0.642034255824 var: 0.464744222225

# %%
print(sum(x is None for x in poly_pair_dsts))
# Out:
# 0

# %% [markdown]
# #### This has been my approach to looking at the distances between polylines with aligning endpoints. I started by finding all distances between activity start locations. Since this would be a symmetric array, to save computations i set the lower half of the array equal to -1. I then picked only pairs of indices who's start locations were closer than 0.01 (units in degrees of latitude and longitude (this is probably OK for now but a more accurate distance would be to compute distance between points on the surface of a sphere). Next, for each pair, I decode the polylines, check to make sure the end points are closer than 0.01, and if yes, I remove a sample from the longer of the two polylines so that they are the same length. Once the same length, distance can be calculated between the polylines. I added them to a list to see what the distributions on distances with similar start and end locations looks like. Noteably, they are most likely close together which is what we expect.

# %%
subset_pairs = []
for idx1, other_idxs in start_clusters.iteritems():
    for idx2 in other_idxs:
        poly1 = np.array(polyline.decode(df.ix[idx1, 'map_summary_polyline'])).flatten()
        poly2 = np.array(polyline.decode(df.ix[idx2, 'map_summary_polyline'])).flatten()
        dist = conditional_dist(poly1, poly2)
        if dist is not None and dist < 1.0: # if distance between polylines is not None, add to list
            subset_pairs.append([idx1, idx2])

# %%
df['activity_id'] = 0

# %%
final_clusters = make_indexer(subset_pairs) # make new indexer with matching activity key pairs

# %%
copy_final_clusters = final_clusters.copy()
for idx1, other_idxs in copy_final_clusters.iteritems():
    for idx2 in other_idxs:
        final_clusters.pop(idx2, None)

# %%
for idx1, other_idxs in final_clusters.iteritems():
    activity_id = uuid.uuid4().hex[:8] # 8 char activity key
    mask_arr = np.array([idx1] + other_idxs)
    df.loc[mask_arr, ['activity_id']] = activity_id

# %%
final_clusters
# Out:
# {0: [466, 1818, 1873, 2731, 2790, 3904, 7025],
#  1: [216, 547, 1591, 3346, 4471, 5295, 5822, 6595],
#  2: [217,
#   247,
#   364,
#   365,
#   826,
#   1042,
#   1446,
#   1650,
#   1656,
#   1705,
#   1803,
#   1948,
#   2067,
#   2080,
#   2135,
#   2254,
#   2295,
#   2308,
#   2439,
#   2624,
#   2737,
#   2842,
#   3201,
#   3358,
#   3361,
#   3635,
#   3692,
#   4420,
#   4439,
#   4589,
#   4597,
#   4599,
#   4611,
#   4699,
#   4911,
#   4948,
#   5235,
#   5620,
#   5629,
#   5662,
#   5720,
#   5780,
#   5852,
#   5856,
#   5893,
#   5901,
#   5940,
#   6027,
#   6053,
#   6129,
#   6251,
#   6412,
#   6748,
#   6870,
#   6943,
#   6995,
#   7047,
#   7056,
#   7151],
#  3: [541,
#   670,
#   1598,
#   1619,
#   1935,
#   2423,
#   2689,
#   2717,
#   3983,
#   4057,
#   4477,
#   5297,
#   5299],
#  4: [74,
#   84,
#   156,
#   580,
#   585,
#   775,
#   1051,
#   1064,
#   1247,
#   1272,
#   1603,
#   1635,
#   1805,
#   2212,
#   2265,
#   2272,
#   2391,
#   2528,
#   2730,
#   2774,
#   2848,
#   3006,
#   3126,
#   3216,
#   3322,
#   3394,
#   3674,
#   3731,
#   3823,
#   3839,
#   3946,
#   4086,
#   4335,
#   4578,
#   4596,
#   4799,
#   4933,
#   5130,
#   5135,
#   5157,
#   5233,
#   5334,
#   5422,
#   5429,
#   5430,
#   5437,
#   5442,
#   5444,
#   5453,
#   5680,
#   5854,
#   6017,
#   6018,
#   6112,
#   6157,
#   6321,
#   6380,
#   6437,
#   6590,
#   6796,
#   6876,
#   6903,
#   6928,
#   7008,
#   7079],
#  5: [253, 3369, 4428],
#  6: [275, 2596, 5021],
#  8: [1987, 1988, 2149, 2494, 2536, 3060, 3882, 4609, 4683, 5168, 6123],
#  11: [1439, 3584, 3957],
#  13: [16,
#   358,
#   491,
#   524,
#   669,
#   827,
#   844,
#   873,
#   919,
#   1032,
#   1207,
#   1380,
#   1436,
#   1459,
#   1476,
#   1680,
#   1780,
#   1923,
#   2004,
#   2511,
#   2675,
#   2850,
#   2926,
#   2949,
#   2971,
#   3099,
#   3113,
#   3525,
#   3551,
#   3637,
#   3643,
#   3695,
#   3719,
#   3764,
#   3814,
#   3912,
#   4078,
#   4307,
#   4311,
#   4380,
#   4590,
#   4899,
#   5024,
#   5134,
#   5340,
#   5436,
#   5598,
#   5733,
#   5767,
#   6043,
#   6132,
#   6172,
#   6174,
#   6294,
#   6346,
#   6407,
#   6427,
#   6440,
#   6476,
#   6501,
#   6566,
#   7013,
#   7088,
#   7111,
#   7126,
#   7130],
#  14: [63,
#   549,
#   580,
#   775,
#   1109,
#   2623,
#   2676,
#   3737,
#   4521,
#   4684,
#   4693,
#   4943,
#   5196,
#   5422,
#   5854,
#   5953,
#   6112,
#   6211],
#  15: [137,
#   181,
#   346,
#   530,
#   532,
#   648,
#   743,
#   926,
#   1017,
#   1119,
#   1182,
#   1692,
#   1757,
#   1840,
#   2298,
#   2357,
#   2765,
#   2840,
#   2993,
#   3171,
#   3527,
#   3539,
#   3592,
#   3666,
#   3720,
#   3827,
#   3992,
#   4229,
#   4324,
#   4364,
#   4385,
#   4754,
#   4829,
#   5006,
#   5354,
#   5613,
#   5957,
#   6115,
#   6169,
#   6233,
#   6520,
#   6713,
#   6881,
#   6930],
#  17: [1971, 5144],
#  19: [1005,
#   1465,
#   1946,
#   2344,
#   3064,
#   3374,
#   3729,
#   3902,
#   3918,
#   4416,
#   5520,
#   5628,
#   5798,
#   6405,
#   6967],
#  20: [136,
#   431,
#   948,
#   1044,
#   1134,
#   1177,
#   1278,
#   1494,
#   1846,
#   1849,
#   2084,
#   2152,
#   2174,
#   2183,
#   2650,
#   2677,
#   3092,
#   3306,
#   3552,
#   4066,
#   4206,
#   4434,
#   4547,
#   4714,
#   4765,
#   4802,
#   5070,
#   5184,
#   5243,
#   5586,
#   5929,
#   5956,
#   6291,
#   6306,
#   6657,
#   6786,
#   7023,
#   7024],
#  21: [22,
#   125,
#   134,
#   196,
#   520,
#   535,
#   763,
#   982,
#   1115,
#   1357,
#   1398,
#   1525,
#   2055,
#   2079,
#   3620,
#   3938,
#   4408,
#   4411,
#   4454,
#   4615,
#   4618,
#   4671,
#   4673,
#   4809,
#   4946,
#   4954,
#   5246,
#   5799,
#   5959,
#   6182,
#   6283,
#   6469,
#   6562,
#   6612,
#   6648,
#   6662,
#   6852,
#   7136],
#  23: [2556],
#  24: [391, 641, 1882, 2050, 2714, 5866, 6063, 6064, 6076],
#  25: [1696, 3324, 3986, 4058, 6803],
#  26: [237,
#   241,
#   248,
#   258,
#   306,
#   362,
#   405,
#   482,
#   522,
#   556,
#   651,
#   660,
#   686,
#   741,
#   853,
#   862,
#   879,
#   892,
#   1022,
#   1085,
#   1099,
#   1132,
#   1166,
#   1228,
#   1297,
#   1307,
#   1329,
#   1366,
#   1368,
#   1409,
#   1423,
#   1428,
#   1553,
#   1560,
#   1578,
#   1605,
#   1610,
#   1666,
#   1675,
#   1809,
#   1845,
#   1854,
#   1892,
#   1899,
#   1909,
#   2043,
#   2052,
#   2059,
#   2064,
#   2072,
#   2097,
#   2129,
#   2374,
#   2394,
#   2395,
#   2438,
#   2450,
#   2533,
#   2537,
#   2629,
#   2635,
#   2644,
#   2660,
#   2683,
#   2694,
#   2721,
#   2732,
#   2861,
#   2864,
#   2871,
#   2908,
#   2932,
#   2964,
#   2984,
#   2994,
#   3038,
#   3087,
#   3117,
#   3121,
#   3165,
#   3166,
#   3279,
#   3351,
#   3359,
#   3414,
#   3419,
#   3434,
#   3541,
#   3550,
#   3586,
#   3589,
#   3598,
#   3617,
#   3626,
#   3639,
#   3676,
#   3755,
#   3770,
#   3775,
#   3795,
#   3806,
#   3828,
#   3856,
#   3909,
#   3944,
#   4000,
#   4043,
#   4124,
#   4125,
#   4163,
#   4211,
#   4313,
#   4322,
#   4343,
#   4360,
#   4401,
#   4423,
#   4456,
#   4470,
#   4518,
#   4548,
#   4604,
#   4607,
#   4623,
#   4660,
#   4669,
#   4678,
#   4715,
#   4722,
#   4726,
#   4761,
#   4780,
#   4783,
#   4882,
#   4903,
#   4936,
#   4973,
#   5031,
#   5040,
#   5051,
#   5073,
#   5077,
#   5104,
#   5114,
#   5115,
#   5193,
#   5200,
#   5207,
#   5212,
#   5213,
#   5219,
#   5226,
#   5228,
#   5239,
#   5273,
#   5322,
#   5371,
#   5401,
#   5408,
#   5428,
#   5432,
#   5469,
#   5546,
#   5547,
#   5575,
#   5601,
#   5604,
#   5606,
#   5608,
#   5611,
#   5640,
#   5691,
#   5697,
#   5704,
#   5738,
#   5786,
#   5808,
#   5817,
#   5834,
#   5835,
#   5885,
#   5945,
#   5982,
#   6008,
#   6020,
#   6035,
#   6069,
#   6099,
#   6119,
#   6121,
#   6146,
#   6149,
#   6161,
#   6181,
#   6190,
#   6230,
#   6253,
#   6255,
#   6266,
#   6279,
#   6284,
#   6357,
#   6371,
#   6385,
#   6389,
#   6419,
#   6444,
#   6463,
#   6495,
#   6555,
#   6570,
#   6631,
#   6653,
#   6665,
#   6675,
#   6733,
#   6750,
#   6751,
#   6756,
#   6770,
#   6810,
#   6820,
#   6900,
#   6910,
#   6955,
#   6958,
#   6978,
#   6979,
#   7005,
#   7007,
#   7132,
#   7156],
#  27: [6208],
#  28: [1759, 3369, 4119, 4428],
#  29: [331, 1112, 2613, 6479, 6591],
#  30: [127,
#   292,
#   539,
#   630,
#   643,
#   692,
#   881,
#   957,
#   992,
#   996,
#   1038,
#   1093,
#   1148,
#   1167,
#   1172,
#   1199,
#   1254,
#   1256,
#   1444,
#   1512,
#   1735,
#   1852,
#   1890,
#   1957,
#   1972,
#   2006,
#   2016,
#   2099,
#   2100,
#   2102,
#   2238,
#   2371,
#   2375,
#   2377,
#   2411,
#   2431,
#   2433,
#   2455,
#   2457,
#   2462,
#   2469,
#   2529,
#   2541,
#   2667,
#   2729,
#   2789,
#   2866,
#   3149,
#   3172,
#   3192,
#   3199,
#   3319,
#   3590,
#   3625,
#   3662,
#   3780,
#   3859,
#   3960,
#   4036,
#   4062,
#   4093,
#   4130,
#   4179,
#   4191,
#   4232,
#   4593,
#   4635,
#   4975,
#   5012,
#   5044,
#   5088,
#   5141,
#   5308,
#   5310,
#   5506,
#   5609,
#   5708,
#   5860,
#   6114,
#   6245,
#   6278,
#   6450,
#   6586,
#   6651,
#   6769,
#   7021,
#   7107],
#  31: [230,
#   267,
#   354,
#   616,
#   672,
#   748,
#   856,
#   1662,
#   1778,
#   1942,
#   1959,
#   1986,
#   3014,
#   3162,
#   3271,
#   4483,
#   4672,
#   5569,
#   5930,
#   6549,
#   6703,
#   6843,
#   6939,
#   7052],
#  32: [2325, 2693, 3158, 3934, 4501, 4511, 4575, 4834, 6877],
#  33: [41,
#   116,
#   613,
#   877,
#   1136,
#   1599,
#   1712,
#   1908,
#   1989,
#   2085,
#   2215,
#   2264,
#   2346,
#   2429,
#   2492,
#   2633,
#   3029,
#   3239,
#   3315,
#   3445,
#   3459,
#   3488,
#   3517,
#   4110,
#   4113,
#   4114,
#   4117,
#   4131,
#   4137,
#   4149,
#   4164,
#   4288,
#   4533,
#   4568,
#   4690,
#   4785,
#   4964,
#   4970,
#   5231,
#   5927,
#   6085,
#   6246,
#   6421,
#   6446,
#   6660,
#   6961],
#  34: [668,
#   899,
#   1080,
#   1646,
#   1819,
#   2230,
#   2397,
#   2735,
#   2788,
#   2794,
#   3504,
#   3645,
#   3970,
#   4051,
#   4304,
#   4927,
#   4941,
#   5776,
#   5803,
#   6098,
#   6508,
#   6516,
#   6557,
#   6712],
#  35: [2720, 2825],
#  36: [373,
#   388,
#   1212,
#   1563,
#   2077,
#   2954,
#   3748,
#   3966,
#   4698,
#   6021,
#   6435,
#   7095,
#   7098,
#   7101,
#   7102,
#   7105,
#   7109,
#   7110,
#   7112,
#   7118],
#  37: [1807, 2659, 3564, 3663, 6415, 6778],
#  38: [164, 1048, 1546, 3796, 7129],
#  39: [186, 1415, 1829, 4267, 4713, 5204, 5327, 5341, 5551],
#  42: [766,
#   791,
#   792,
#   851,
#   1063,
#   1164,
#   1171,
#   1551,
#   1607,
#   1763,
#   1766,
#   1768,
#   2384,
#   2602,
#   2787,
#   2940,
#   3032,
#   3057,
#   3107,
#   3324,
#   3338,
#   3725,
#   3803,
#   3986,
#   4058,
#   4067,
#   4095,
#   4892,
#   4989,
#   5896,
#   6138,
#   6507,
#   6803,
#   7104,
#   7120],
#  43: [2418, 2738, 2877, 3846, 5612, 6128, 6465, 6992, 7074],
#  44: [108,
#   165,
#   222,
#   529,
#   740,
#   768,
#   822,
#   845,
#   911,
#   940,
#   1055,
#   1092,
#   1178,
#   1303,
#   1410,
#   1429,
#   1442,
#   1638,
#   1706,
#   1775,
#   1813,
#   1860,
#   1861,
#   1933,
#   1956,
#   2051,
#   2136,
#   2177,
#   2206,
#   2289,
#   2389,
#   2407,
#   2483,
#   2505,
#   2530,
#   2547,
#   2646,
#   2829,
#   2839,
#   2935,
#   2989,
#   3028,
#   3110,
#   3120,
#   3128,
#   3403,
#   3513,
#   3557,
#   3648,
#   3932,
#   4035,
#   4079,
#   4166,
#   4167,
#   4375,
#   4379,
#   4459,
#   4474,
#   4539,
#   4636,
#   4704,
#   4900,
#   4950,
#   4951,
#   5015,
#   5407,
#   5420,
#   5647,
#   5863,
#   5881,
#   5914,
#   5961,
#   5988,
#   6200,
#   6285,
#   6299,
#   6699,
#   6707,
#   6847,
#   6997,
#   7158],
#  45: [503, 681, 2092, 2181, 3045, 5714, 7085],
#  47: [52,
#   58,
#   174,
#   175,
#   375,
#   397,
#   442,
#   512,
#   536,
#   608,
#   657,
#   683,
#   684,
#   717,
#   750,
#   821,
#   841,
#   843,
#   889,
#   928,
#   1057,
#   1094,
#   1116,
#   1200,
#   1274,
#   1279,
#   1412,
#   1614,
#   1653,
#   1681,
#   1733,
#   1740,
#   1745,
#   1751,
#   1752,
#   1754,
#   1821,
#   1867,
#   1991,
#   1994,
#   2048,
#   2088,
#   2093,
#   2113,
#   2207,
#   2323,
#   2378,
#   2467,
#   2572,
#   2573,
#   2768,
#   2801,
#   2814,
#   2886,
#   2952,
#   3003,
#   3090,
#   3155,
#   3218,
#   3389,
#   3454,
#   3512,
#   3520,
#   3533,
#   3588,
#   3622,
#   3687,
#   3709,
#   3745,
#   3758,
#   3782,
#   3798,
#   3812,
#   3874,
#   3914,
#   4116,
#   4292,
#   4377,
#   4419,
#   4488,
#   4577,
#   4605,
#   4830,
#   4849,
#   4880,
#   4896,
#   4997,
#   5116,
#   5124,
#   5143,
#   5223,
#   5280,
#   5313,
#   5375,
#   5396,
#   5410,
#   5519,
#   5646,
#   5753,
#   5791,
#   5810,
#   5876,
#   5967,
#   5978,
#   6130,
#   6150,
#   6160,
#   6166,
#   6209,
#   6289,
#   6348,
#   6408,
#   6424,
#   6456,
#   6492,
#   6625,
#   6632,
#   6644,
#   6647,
#   6837,
#   6861,
#   6938,
#   6941,
#   6949,
#   6951,
#   7043,
#   7080,
#   7138],
#  48: [323,
#   340,
#   368,
#   624,
#   1185,
#   1223,
#   1238,
#   1425,
#   1674,
#   2040,
#   2138,
#   2237,
#   2338,
#   2464,
#   2531,
#   2740,
#   3466,
#   3593,
#   3611,
#   4586,
#   4914,
#   4995,
#   5087,
#   5372,
#   5471,
#   5500,
#   5621,
#   5838,
#   5965,
#   5996,
#   6248,
#   6286,
#   6498,
#   6499,
#   6514,
#   6588,
#   6716,
#   6719,
#   6815,
#   6869,
#   6924],
#  49: [884, 1545, 1779, 3049, 3749, 3911, 5760],
#  50: [111,
#   287,
#   325,
#   338,
#   501,
#   767,
#   816,
#   1248,
#   1430,
#   1730,
#   2141,
#   2154,
#   2178,
#   2302,
#   2522,
#   2725,
#   3097,
#   3249,
#   3380,
#   3431,
#   3885,
#   4279,
#   4373,
#   4514,
#   4701,
#   4883,
#   5056,
#   5342,
#   5811,
#   5898,
#   6001,
#   6287,
#   6865,
#   7071,
#   7078],
#  51: [254,
#   555,
#   719,
#   823,
#   938,
#   1921,
#   2081,
#   2342,
#   2442,
#   3016,
#   3212,
#   3470,
#   3531,
#   3854,
#   3961,
#   4566,
#   5017,
#   5126,
#   5264,
#   5729],
#  53: [350,
#   720,
#   2221,
#   2373,
#   2657,
#   2687,
#   2793,
#   2880,
#   3421,
#   3503,
#   3537,
#   3981,
#   3996,
#   4314,
#   4963,
#   5090,
#   5564,
#   5718,
#   5880,
#   6051,
#   6258,
#   6671],
#  54: [233,
#   302,
#   751,
#   1069,
#   1388,
#   1523,
#   1565,
#   1749,
#   1914,
#   2586,
#   2742,
#   2884,
#   3035,
#   4345,
#   4569,
#   5020,
#   5079,
#   5113,
#   5232,
#   5347,
#   5630,
#   5806,
#   6222,
#   6649,
#   6907,
#   7073],
#  55: [1268, 1663, 1965, 2553, 3582, 5418, 5591, 5951, 6663, 6701],
#  56: [60,
#   66,
#   71,
#   78,
#   265,
#   1995,
#   2057,
#   2061,
#   2164,
#   2166,
#   2167,
#   2507,
#   2513,
#   2518,
#   3714,
#   3739,
#   3744,
#   4208,
#   4239,
#   4389,
#   5894,
#   5924,
#   5941,
#   6010,
#   6086,
#   6090,
#   6094,
#   6103,
#   6237],
#  57: [390, 5296, 5983],
#  59: [101,
#   215,
#   232,
#   609,
#   1027,
#   1141,
#   1244,
#   1580,
#   1612,
#   1688,
#   2509,
#   2524,
#   3272,
#   3492,
#   3835,
#   3968,
#   4475,
#   5058,
#   5275,
#   5530,
#   5544,
#   5554,
#   5785,
#   5882,
#   5911,
#   6042,
#   6080,
#   6083,
#   6232,
#   6301,
#   6478,
#   6728,
#   6857,
#   7030],
#  61: [417,
#   848,
#   1129,
#   1322,
#   2023,
#   2468,
#   2815,
#   2872,
#   3573,
#   4226,
#   4868,
#   4871,
#   5678,
#   5747,
#   7037,
#   7041],
#  62: [1799, 1800, 3263, 7115],
#  64: [1555, 2186, 2726, 3342, 3474, 4487, 4493, 6298, 6711, 6732, 6801],
#  65: [329,
#   923,
#   1562,
#   1642,
#   1816,
#   2198,
#   2355,
#   2643,
#   3148,
#   3404,
#   3575,
#   3689,
#   3927,
#   4042,
#   4207,
#   4370,
#   4922,
#   4929,
#   5127,
#   5333,
#   6177,
#   6270,
#   6370,
#   6828],
#  67: [1140,
#   1480,
#   1694,
#   2379,
#   3396,
#   3696,
#   3805,
#   5172,
#   5946,
#   6155,
#   6376,
#   6580,
#   6798],
#  69: [367, 858, 2039, 4357, 5170, 6096, 6097],
#  70: [1255, 1269, 1529, 1593, 1929, 4140, 4188, 4750, 5169, 6635, 6678, 6755],
#  72: [257,
#   430,
#   571,
#   981,
#   1091,
#   1432,
#   1949,
#   1981,
#   1993,
#   2044,
#   2284,
#   2388,
#   2585,
#   2654,
#   2786,
#   2804,
#   2854,
#   2999,
#   3039,
#   3058,
#   3062,
#   3109,
#   3505,
#   3602,
#   3897,
#   4076,
#   4616,
#   4637,
#   4832,
#   4983,
#   5495,
#   5777,
#   6311,
#   6509,
#   6554],
#  73: [437,
#   441,
#   562,
#   788,
#   1058,
#   1149,
#   1470,
#   1700,
#   1794,
#   1900,
#   1983,
#   2415,
#   2456,
#   2461,
#   2649,
#   2847,
#   3059,
#   3204,
#   3353,
#   3502,
#   3571,
#   3900,
#   4156,
#   4289,
#   4718,
#   4923,
#   4969,
#   5063,
#   5365,
#   5518,
#   5793,
#   5846,
#   5907,
#   5997,
#   6105,
#   6135,
#   6148,
#   6365,
#   6534,
#   6550,
#   6814,
#   6988],
#  75: [181,
#   346,
#   389,
#   530,
#   532,
#   1119,
#   2357,
#   2765,
#   3592,
#   3992,
#   4229,
#   4364,
#   4829,
#   5006,
#   5957,
#   6602,
#   6713,
#   6881,
#   6930],
#  76: [83, 807, 1083, 1640, 2490, 3461, 3858, 4003, 4266, 4628],
#  77: [761, 2156, 2883, 3011, 3178, 3184, 3376, 3405, 3508, 5266, 5639, 7002],
#  79: [1313, 3857, 6423],
#  81: [3653],
#  85: [553, 590, 723, 1549, 1837, 3349, 4017, 4040, 4396, 5179, 6060, 6377],
#  88: [329,
#   400,
#   584,
#   2355,
#   3111,
#   3130,
#   3302,
#   3390,
#   3757,
#   3927,
#   4042,
#   4111,
#   5333,
#   5357,
#   5614,
#   6147,
#   6270,
#   6370,
#   6725,
#   6902],
#  89: [289, 1522, 3443, 5616, 6025, 6443, 6510, 6574, 6702, 6775, 6780, 6817],
#  90: [163,
#   210,
#   255,
#   385,
#   510,
#   713,
#   793,
#   801,
#   803,
#   1869,
#   2005,
#   2245,
#   2393,
#   2434,
#   2565,
#   2734,
#   2844,
#   3094,
#   3223,
#   3452,
#   4274,
#   4293,
#   4320,
#   4498,
#   4766,
#   5069,
#   5111,
#   5534,
#   5935,
#   6029,
#   6031,
#   6250,
#   6396,
#   6849],
#  91: [553, 3349, 3956, 6060, 6942],
#  92: [819, 883, 1341, 2712, 3647, 5256, 5832, 5952],
#  93: [178,
#   180,
#   250,
#   337,
#   428,
#   476,
#   488,
#   542,
#   611,
#   715,
#   738,
#   759,
#   776,
#   944,
#   1001,
#   1062,
#   1186,
#   1271,
#   1325,
#   1345,
#   1471,
#   1577,
#   1609,
#   1615,
#   1622,
#   1764,
#   1765,
#   1938,
#   1977,
#   2032,
#   2132,
#   2286,
#   2392,
#   2399,
#   2630,
#   2819,
#   2845,
#   2910,
#   2991,
#   3013,
#   3221,
#   3266,
#   3292,
#   3298,
#   3345,
#   3684,
#   3685,
#   3750,
#   3785,
#   3816,
#   3826,
#   3993,
#   4400,
#   4573,
#   4695,
#   4867,
#   4952,
#   5025,
#   5054,
#   5064,
#   5155,
#   5248,
#   5385,
#   5492,
#   5501,
#   5872,
#   5884,
#   6116,
#   6124,
#   6171,
#   6921,
#   6932,
#   7034],
#  94: [5034],
#  95: [410,
#   645,
#   1370,
#   1623,
#   1717,
#   1720,
#   2697,
#   3347,
#   3623,
#   3818,
#   3867,
#   3941,
#   4075,
#   5229,
#   6095,
#   6263,
#   6305],
#  96: [3721, 3738, 5857, 6304],
#  97: [531,
#   644,
#   949,
#   958,
#   1486,
#   2078,
#   2087,
#   2970,
#   3222,
#   3704,
#   3933,
#   4472,
#   4608,
#   4638,
#   4738,
#   5032,
#   6475,
#   6607,
#   7031],
#  98: [176,
#   226,
#   301,
#   356,
#   485,
#   573,
#   712,
#   721,
#   731,
#   869,
#   984,
#   1082,
#   1138,
#   1257,
#   1481,
#   1508,
#   1788,
#   1793,
#   1847,
#   1848,
#   2037,
#   2054,
#   2175,
#   2185,
#   2316,
#   2463,
#   2519,
#   2568,
#   2948,
#   3140,
#   3150,
#   3275,
#   3464,
#   3515,
#   3521,
#   3580,
#   3876,
#   3975,
#   4138,
#   4591,
#   4621,
#   4968,
#   5244,
#   5329,
#   5419,
#   5503,
#   5556,
#   5633,
#   5664,
#   5673,
#   5823,
#   5908,
#   6068,
#   6422,
#   6503,
#   6720,
#   6904,
#   6966,
#   7124],
#  99: [153,
#   352,
#   752,
#   904,
#   1117,
#   1318,
#   1326,
#   1464,
#   2030,
#   2107,
#   2170,
#   2228,
#   2335,
#   2354,
#   2476,
#   2499,
#   2996,
#   3044,
#   3196,
#   3219,
#   3366,
#   3397,
#   3446,
#   3484,
#   3711,
#   4061,
#   4077,
#   4767,
#   5014,
#   5245,
#   5599,
#   5615,
#   5724,
#   5731,
#   5833,
#   5923,
#   6594,
#   6693,
#   6779,
#   7146],
#  103: [245,
#   274,
#   280,
#   586,
#   942,
#   1205,
#   1213,
#   1402,
#   1690,
#   1691,
#   1941,
#   2007,
#   2477,
#   2707,
#   3161,
#   3378,
#   3386,
#   3413,
#   3572,
#   3756,
#   4033,
#   4355,
#   4436,
#   4710,
#   4737,
#   4877,
#   5092,
#   5103,
#   5185,
#   5464,
#   5488,
#   5795,
#   6688,
#   6824,
#   6933],
#  105: [167, 1208, 3211, 3471, 6274],
#  106: [266,
#   284,
#   432,
#   507,
#   514,
#   603,
#   707,
#   804,
#   1239,
#   1267,
#   1276,
#   1687,
#   1732,
#   2008,
#   2340,
#   2437,
#   2610,
#   2975,
#   3061,
#   3146,
#   3210,
#   3236,
#   3355,
#   3392,
#   3437,
#   3619,
#   3638,
#   3722,
#   4404,
#   4409,
#   4581,
#   4902,
#   4976,
#   4979,
#   5125,
#   5180,
#   5435,
#   5475,
#   5592,
#   5594,
#   5663,
#   5713,
#   6142,
#   6342,
#   6470,
#   6616,
#   6771,
#   6774,
#   6839,
#   6920],
#  107: [619, 622, 912, 1124, 1348, 1576, 3124, 3127, 5792, 6023],
#  109: [933, 963, 1043, 3229, 4406, 6238, 7010, 7116],
#  110: [1318, 1326, 2030, 2228, 3366, 5833],
#  113: [2852, 5545, 6506],
#  114: [226,
#   343,
#   349,
#   485,
#   656,
#   730,
#   869,
#   2571,
#   2592,
#   2639,
#   4291,
#   5503,
#   5579,
#   6323,
#   6449,
#   6576,
#   7060],
#  117: [632,
#   846,
#   2075,
#   2688,
#   3046,
#   3608,
#   4089,
#   4796,
#   5595,
#   5821,
#   6070,
#   6272,
#   6636,
#   7055,
#   7094],
#  118: [2025, 2252, 4629, 5403, 6195],
#  119: [506,
#   589,
#   1111,
#   1756,
#   2695,
#   2895,
#   3501,
#   3581,
#   4369,
#   4825,
#   4955,
#   5062,
#   5081,
#   5960,
#   5994],
#  120: [126],
#  121: [828,
#   829,
#   1052,
#   1503,
#   2257,
#   2361,
#   2413,
#   2414,
#   2916,
#   3069,
#   3400,
#   3465,
#   3971,
#   4121,
#   4215,
#   4817,
#   5263,
#   5414,
#   5558,
#   5602,
#   5904,
#   6545,
#   6698,
#   6901],
#  122: [636, 1243, 2121, 3183, 4844, 4931, 5474, 6571, 6749, 6952],
#  124: [1877, 4667, 4949, 5543, 5825, 6011, 6092, 6401, 6459],
#  128: [353, 616, 1219, 2888, 2979, 6703, 6939],
#  129: [137,
#   346,
#   530,
#   532,
#   648,
#   1395,
#   1692,
#   1757,
#   2053,
#   2298,
#   2357,
#   2792,
#   3171,
#   3527,
#   3539,
#   3827,
#   3992,
#   4229,
#   4654,
#   4754,
#   5957,
#   6233,
#   6713,
#   6881],
#  130: [3145],
#  131: [2718, 3268, 3277, 3566, 6519],
#  132: [228, 433, 1836, 2238, 2455, 3149, 3761, 4564, 5251],
#  133: [190,
#   192,
#   409,
#   521,
#   1066,
#   1090,
#   1156,
#   1548,
#   1624,
#   1881,
#   1889,
#   1944,
#   2026,
#   2090,
#   2233,
#   2951,
#   2955,
#   2960,
#   2967,
#   2974,
#   3009,
#   3244,
#   3248,
#   3258,
#   3365,
#   3409,
#   3545,
#   3604,
#   3708,
#   3855,
#   3913,
#   3924,
#   4101,
#   4236,
#   4248,
#   4250,
#   4252,
#   4254,
#   4255,
#   4259,
#   4260,
#   4262,
#   4263,
#   4336,
#   4402,
#   4425,
#   4645,
#   4733,
#   5215,
#   5265,
#   6296,
#   6485,
#   6844,
#   6846,
#   6851],
#  135: [154,
#   415,
#   1151,
#   1169,
#   1174,
#   1354,
#   1378,
#   1479,
#   1552,
#   1568,
#   2073,
#   2188,
#   2472,
#   3317,
#   3430,
#   3627,
#   3671,
#   3849,
#   4346,
#   4352,
#   4361,
#   4368,
#   4520,
#   4739,
#   4741,
#   4743,
#   4748,
#   4752,
#   4757,
#   4822,
#   4848,
#   5078,
#   5363,
#   6577,
#   6744,
#   6776,
#   6783,
#   6809],
#  138: [4450],
#  140: [149,
#   594,
#   1575,
#   1631,
#   1686,
#   3112,
#   3449,
#   3701,
#   3728,
#   3766,
#   4085,
#   4126,
#   5035,
#   5098,
#   5220,
#   5288,
#   6039,
#   6058,
#   6067,
#   6614,
#   6628,
#   7044],
#  141: [953, 3129],
#  142: [623, 2481, 2578, 3724, 3991, 5766, 6946],
#  143: [7129],
#  148: [155, 4223],
#  151: [550, 1225, 2380, 3880, 4068, 6351],
#  157: [226,
#   485,
#   573,
#   869,
#   984,
#   1138,
#   1481,
#   1788,
#   2062,
#   2962,
#   3275,
#   3515,
#   3876,
#   4005,
#   4621,
#   5503,
#   5673,
#   6503,
#   6966,
#   7054],
#  158: [239,
#   560,
#   618,
#   696,
#   700,
#   1265,
#   1531,
#   1864,
#   2244,
#   2427,
#   2942,
#   3309,
#   4090,
#   4895,
#   5160,
#   6084,
#   6297,
#   6310],
#  159: [2267,
#   3072,
#   3096,
#   3754,
#   5106,
#   5610,
#   5658,
#   5661,
#   5672,
#   5675,
#   5676,
#   5683,
#   5684],
#  160: [796,
#   1648,
#   1679,
#   1876,
#   2137,
#   2223,
#   2550,
#   2567,
#   2820,
#   3565,
#   4246,
#   4278,
#   5082,
#   5651,
#   5966,
#   6013,
#   6026,
#   6552,
#   6620,
#   6623],
#  161: [277, 1000, 1968, 4099],
#  162: [990, 2803, 3529, 4353, 5947, 6575],
#  166: [4538],
#  168: [5600, 6805],
#  169: [5567],
#  170: [4031],
#  172: [444,
#   462,
#   467,
#   468,
#   481,
#   583,
#   649,
#   661,
#   679,
#   818,
#   917,
#   967,
#   1249,
#   1250,
#   1382,
#   1478,
#   1484,
#   1485,
#   1533,
#   1815,
#   1824,
#   1856,
#   1874,
#   1898,
#   1911,
#   2033,
#   2172,
#   2430,
#   2548,
#   2594,
#   2953,
#   3286,
#   3511,
#   3535,
#   3774,
#   3890,
#   3928,
#   4258,
#   4390,
#   4407,
#   4442,
#   4457,
#   4461,
#   4662,
#   4986,
#   4992,
#   5128,
#   5416,
#   5439,
#   5781,
#   5919,
#   6117,
#   6152,
#   6210,
#   6215,
#   6280,
#   6336,
#   6360,
#   6795,
#   6968,
#   6998,
#   7134,
#   7140],
#  173: [2770, 3391, 4418],
#  177: [4372],
#  179: [278,
#   1155,
#   1417,
#   2271,
#   2776,
#   3563,
#   3651,
#   3829,
#   4168,
#   4182,
#   4345,
#   4833,
#   5113,
#   5806,
#   6579,
#   6709,
#   7073],
#  182: [2161, 3186, 3681, 3783, 4030, 4227, 4276, 4730, 5763],
#  183: [1209, 3220, 4999, 5339, 5761],
#  184: [611,
#   1001,
#   1191,
#   1471,
#   1615,
#   1636,
#   1765,
#   3221,
#   3816,
#   4400,
#   5054,
#   5064,
#   6932],
#  185: [5693],
#  189: [593, 2715, 3929, 4038, 4821, 5522, 6303, 6694, 6715],
#  191: [195, 440, 1777, 4214],
#  193: [876,
#   1440,
#   2609,
#   2874,
#   3654,
#   3820,
#   4070,
#   4639,
#   4720,
#   5209,
#   5559,
#   6154,
#   6269,
#   6382,
#   6922,
#   6993],
#  194: [537, 1806, 2109, 3311, 3462, 3921, 4595, 4613, 5873, 6633, 7093],
#  197: [1575, 2484, 2637, 3112, 3735, 5098, 6039],
#  198: [582, 1045, 3463, 6417, 6474],
#  200: [461, 1601, 3329, 4240, 6131],
#  203: [329,
#   400,
#   584,
#   1925,
#   2355,
#   3111,
#   3390,
#   3927,
#   4042,
#   5333,
#   6147,
#   6270,
#   6370,
#   6725],
#  204: [637, 1047, 2201, 3157, 6032],
#  206: [934, 4100, 4147, 4938, 5700, 5955],
#  207: [5452, 5917],
#  208: [239,
#   551,
#   618,
#   718,
#   960,
#   1571,
#   1862,
#   2552,
#   2599,
#   2746,
#   2986,
#   3518,
#   4561,
#   4725,
#   4912,
#   5085,
#   5160,
#   5642],
#  211: [212,
#   213,
#   214,
#   219,
#   223,
#   227,
#   296,
#   419,
#   1364,
#   1858,
#   2917,
#   3388,
#   3411,
#   3451,
#   3476,
#   3530,
#   3664,
#   4827,
#   6875],
#  220: [936,
#   1013,
#   1034,
#   1270,
#   1812,
#   1990,
#   2110,
#   2486,
#   2510,
#   2620,
#   3063,
#   3420,
#   3429,
#   3825,
#   4024,
#   4054,
#   4087,
#   5423,
#   5451,
#   5796,
#   5807,
#   5865,
#   5868,
#   6642,
#   6760,
#   6893],
#  221: [370,
#   706,
#   2140,
#   2218,
#   2421,
#   2527,
#   2757,
#   2997,
#   3040,
#   3426,
#   3746,
#   3781,
#   4920,
#   5177,
#   5754,
#   6766,
#   6971],
#  224: [1371, 2763, 3528],
#  225: [1198,
#   1356,
#   1704,
#   2807,
#   3050,
#   3312,
#   3570,
#   4853,
#   5736,
#   6257,
#   6402,
#   6420,
#   6729,
#   6873],
#  229: [256,
#   451,
#   1049,
#   1282,
#   1400,
#   1405,
#   1498,
#   1504,
#   1617,
#   1673,
#   1907,
#   1916,
#   2117,
#   3022,
#   3299,
#   3489,
#   4174,
#   4371,
#   4921,
#   5107,
#   5330,
#   5343,
#   5631,
#   5859,
#   5943,
#   5989,
#   6206,
#   6235,
#   6654],
#  231: [2416, 3310, 4598],
#  235: [268,
#   667,
#   1665,
#   1811,
#   2367,
#   2506,
#   2590,
#   3189,
#   3616,
#   3686,
#   3723,
#   4776,
#   5836,
#   6556,
#   6929],
#  236: [6378],
#  238: [240, 242, 1231, 1233, 1236, 3751, 3753, 5851],
#  243: [348],
#  246: [435, 927, 3214, 4142, 4348],
#  249: [659, 696, 1864, 2000, 2244, 2387, 2427, 4090, 4572, 5085, 6002, 6310],
#  252: [1292, 3085, 4002, 4555, 4982, 5240, 6168],
#  259: [379,
#   635,
#   647,
#   693,
#   902,
#   930,
#   1024,
#   1150,
#   1224,
#   1586,
#   1728,
#   1738,
#   2095,
#   2290,
#   2385,
#   2420,
#   2603,
#   2782,
#   2836,
#   3387,
#   3646,
#   3727,
#   3866,
#   3873,
#   4185,
#   4296,
#   4374,
#   4476,
#   4567,
#   4619,
#   4855,
#   4889,
#   5577,
#   5742,
#   5750,
#   5933,
#   6066,
#   6102,
#   6107,
#   6198,
#   6535,
#   6536,
#   6639,
#   6792,
#   6842,
#   6895,
#   7154],
#  260: [333, 629, 864, 1537, 1600, 6045, 6275, 6276],
#  262: [3198, 3200, 3217, 3227, 3231, 6923],
#  263: [347, 1131, 2479, 6410, 6627],
#  264: [1007, 1079, 2294, 5409, 7108],
#  269: [1817, 4966],
#  270: [439,
#   666,
#   753,
#   945,
#   952,
#   966,
#   1343,
#   1567,
#   1702,
#   1865,
#   2060,
#   2563,
#   2574,
#   2709,
#   2862,
#   2961,
#   3439,
#   3440,
#   3675,
#   3732,
#   3891,
#   3920,
#   3950,
#   4161,
#   4203,
#   4282,
#   4376,
#   4583,
#   4760,
#   4823,
#   4898,
#   4925,
#   5149,
#   5274,
#   5278,
#   5290,
#   5494,
#   5507,
#   5819,
#   5843,
#   5999,
#   6170,
#   6184,
#   6199,
#   6234,
#   6404,
#   6489,
#   6736,
#   6790,
#   6850,
#   6868,
#   6883,
#   6969,
#   6990,
#   7012,
#   7015],
#  272: [2464, 6286],
#  273: [293, 305, 406, 3915],
#  282: [588, 2716, 3154, 3636, 5305, 7076],
#  283: [1466, 1870, 3352, 3363, 4557],
#  285: [802, 2118, 2257, 2413, 3998, 4136, 4215, 4381, 5904],
#  286: [1031, 2508, 4152, 6752],
#  288: [2652, 5879],
#  291: [7076],
#  294: [725, 969, 2179, 3923, 4285, 5916],
#  295: [909, 1121, 3860],
#  300: [4178],
#  304: [1433,
#   2878,
#   3282,
#   3402,
#   4729,
#   4731,
#   5129,
#   5146,
#   5427,
#   5529,
#   5580,
#   6585,
#   6944],
#  307: [1360,
#   1396,
#   1589,
#   2125,
#   2134,
#   2460,
#   2680,
#   2905,
#   3153,
#   3741,
#   4238,
#   4399,
#   4499,
#   5424,
#   5593,
#   5850,
#   6089,
#   6192,
#   6225,
#   6887,
#   7082],
#  308: [359,
#   632,
#   1828,
#   1912,
#   2634,
#   2688,
#   2743,
#   3017,
#   3177,
#   3608,
#   4463,
#   4796,
#   5030,
#   5595,
#   6141,
#   6272,
#   6453,
#   6636,
#   7075],
#  310: [317,
#   447,
#   756,
#   832,
#   1393,
#   1574,
#   2015,
#   2049,
#   2364,
#   2521,
#   2584,
#   2918,
#   3105,
#   3289,
#   3438,
#   3453,
#   4194,
#   4287,
#   4510,
#   4612,
#   4647,
#   4682,
#   4807,
#   4974,
#   5067,
#   5091,
#   5182,
#   5382,
#   5573,
#   5581,
#   5624,
#   6542,
#   6543],
#  311: [580,
#   775,
#   1064,
#   2265,
#   2391,
#   2534,
#   2774,
#   2848,
#   3006,
#   3126,
#   3216,
#   4578,
#   5112,
#   5441,
#   5447,
#   5590,
#   5789,
#   5854,
#   6157,
#   6539,
#   6590],
#  312: [408,
#   1709,
#   1715,
#   2034,
#   2042,
#   2143,
#   3642,
#   4052,
#   4663,
#   4740,
#   4962,
#   6406,
#   6799,
#   6957],
#  313: [321, 3081, 4200],
#  314: [994, 2933, 3412, 3532, 4306, 5101],
#  316: [1639, 1868, 3424, 5328, 6656, 7091, 7111, 7162],
#  318: [455,
#   552,
#   597,
#   910,
#   1602,
#   1658,
#   2288,
#   2409,
#   4159,
#   4177,
#   4342,
#   4574,
#   5360,
#   5499,
#   6065,
#   6087,
#   6430,
#   6434,
#   6722,
#   7145],
#  320: [1774],
#  324: [979, 2466, 3656, 5498],
#  327: [6369],
#  328: [871, 903, 2027, 3170, 3225, 3333, 6356, 6739],
#  330: [474, 650, 782, 1293, 2022, 3004, 3433, 3717, 3931, 5411, 5448, 6392],
#  332: [1351],
#  334: [413,
#   495,
#   500,
#   1784,
#   1901,
#   1978,
#   2236,
#   2404,
#   2812,
#   3457,
#   3655,
#   3693,
#   6447,
#   6704],
#  335: [2229, 5920],
#  336: [2587, 3613, 4041, 4128, 5388, 5721],
#  344: [3234, 4184],
#  345: [893, 1961, 4358, 6387, 7117],
#  351: [767, 1430, 2600],
#  355: [2234],
#  363: [1471, 1615, 1765, 2910, 4765, 5929],
#  366: [509, 621, 977, 987, 1473, 1770, 1826, 2231, 2365, 4172, 4271, 5690],
#  369: [943,
#   1188,
#   1251,
#   2324,
#   2336,
#   2927,
#   3327,
#   4139,
#   4696,
#   5140,
#   5158,
#   5162,
#   5203,
#   5743,
#   6457,
#   7065,
#   7127],
#  371: [1075, 1076, 1078, 1294, 4571, 5744, 7087],
#  372: [5963],
#  374: [935, 2451, 2656, 4387, 5510, 5734, 6438, 6759, 6866, 6950, 7096],
#  376: [873],
#  378: [4129],
#  381: [1192, 5289, 6906],
#  384: [787, 1089, 3041, 5635],
#  386: [3391],
#  387: [574,
#   690,
#   888,
#   1229,
#   1350,
#   1431,
#   1539,
#   1678,
#   2452,
#   2902,
#   3101,
#   3597,
#   3697,
#   3916,
#   4104,
#   4917,
#   5298,
#   5355,
#   5379,
#   5460,
#   6180],
#  392: [838],
#  393: [5178, 6917],
#  396: [906, 1358, 5010, 5208, 5668, 6436, 6757, 7067],
#  403: [767, 816, 2600, 3431, 5811],
#  404: [799,
#   2147,
#   2255,
#   2453,
#   3024,
#   3845,
#   5019,
#   5291,
#   5397,
#   5467,
#   5479,
#   5489,
#   5782,
#   6368],
#  407: [2291, 4025],
#  411: [1232, 3313, 3926, 5849],
#  412: [1667, 4630, 5300, 7069],
#  414: [1985,
#   2699,
#   3197,
#   3536,
#   3632,
#   3712,
#   3772,
#   3822,
#   3864,
#   4559,
#   4689,
#   4862,
#   5332,
#   5502,
#   6320],
#  416: [2783, 4680],
#  421: [1301,
#   1305,
#   1306,
#   1308,
#   1309,
#   1312,
#   1315,
#   1324,
#   1327,
#   1328,
#   1330,
#   1332,
#   3375,
#   3844,
#   5654],
#  422: [849, 4661],
#  423: [613, 863, 877, 1659, 1908, 2119, 4131],
#  424: [3614],
#  425: [434, 612, 2029, 2031, 5552],
#  429: [534,
#   1237,
#   1458,
#   1833,
#   2642,
#   2702,
#   3076,
#   3768,
#   3850,
#   4576,
#   4674,
#   5218,
#   5756,
#   5831],
#  438: [765, 1226, 1259, 1467, 1762, 1814, 2390, 2601, 2899, 4220, 4582, 4774],
#  446: [605,
#   854,
#   1189,
#   1637,
#   1698,
#   1755,
#   1839,
#   2126,
#   2644,
#   2648,
#   3065,
#   3253,
#   3381,
#   3485,
#   3499,
#   3558,
#   3817,
#   3930,
#   3972,
#   4909,
#   5023,
#   5302,
#   6061,
#   6134,
#   6640,
#   6675,
#   6931],
#  448: [531,
#   847,
#   949,
#   1486,
#   2213,
#   3314,
#   3933,
#   4218,
#   4472,
#   4608,
#   4638,
#   4700,
#   5032,
#   5732,
#   6475,
#   7031],
#  450: [1414,
#   3102,
#   3144,
#   3448,
#   4201,
#   4462,
#   4485,
#   4644,
#   5001,
#   5773,
#   7019,
#   7128,
#   7135],
#  452: [5674],
#  453: [3609],
#  454: [543, 1154, 2655, 3300, 7016],
#  456: [747,
#   1441,
#   2091,
#   2106,
#   2251,
#   3278,
#   4173,
#   4812,
#   4835,
#   5043,
#   5370,
#   5539,
#   6743],
#  457: [1394, 1457, 1472, 4256, 5183, 5452, 5828, 5917, 6983, 7099],
#  459: [868],
#  460: [545, 735, 3868, 3870, 5656, 5918, 7028],
#  463: [602,
#   755,
#   842,
#   1230,
#   1291,
#   1298,
#   1719,
#   1820,
#   1927,
#   1979,
#   3133,
#   3135,
#   3160,
#   3308,
#   3384,
#   4032,
#   4588,
#   5383,
#   5417,
#   5771,
#   5889,
#   6619],
#  464: [3884, 4486],
#  470: [4708, 4782, 6626],
#  471: [1025,
#   1110,
#   1392,
#   1407,
#   1445,
#   1737,
#   1947,
#   1958,
#   2287,
#   3025,
#   3348,
#   4681,
#   4711,
#   4717,
#   5309,
#   5582,
#   5774,
#   5848,
#   6236,
#   6333,
#   6680,
#   6763,
#   6925],
#  472: [2708, 6033],
#  475: [1778],
#  478: [571,
#   820,
#   974,
#   1403,
#   1432,
#   1460,
#   1468,
#   1496,
#   1538,
#   1584,
#   1587,
#   1896,
#   1949,
#   1963,
#   1993,
#   2044,
#   2307,
#   2319,
#   2542,
#   2638,
#   2786,
#   2813,
#   2999,
#   3058,
#   3190,
#   3307,
#   3367,
#   3393,
#   3505,
#   3585,
#   3602,
#   3713,
#   3804,
#   3897,
#   4143,
#   4637,
#   4747,
#   4840,
#   4983,
#   5131,
#   5199,
#   5255,
#   5331,
#   5381,
#   5490,
#   5542,
#   5829,
#   5990,
#   6497,
#   6509,
#   6554,
#   7000,
#   7123],
#  480: [2920, 2922, 4269, 4481, 6934],
#  483: [1313, 2904, 3055, 3857, 4046, 5540, 5625, 6073, 6165, 6423, 6811],
#  484: [609,
#   1059,
#   1244,
#   1369,
#   2232,
#   3491,
#   3492,
#   3894,
#   3968,
#   4475,
#   4854,
#   4908,
#   5150,
#   5366,
#   5554,
#   6042,
#   6384,
#   6728,
#   6742,
#   6857,
#   6985,
#   7030],
#  490: [1797, 2071, 7150],
#  497: [783, 784, 1234, 1786, 2432, 2719, 4319, 5320, 5482, 6687, 6819, 6884],
#  498: [4998],
#  504: [736, 3326, 3332, 3901, 4786, 4790, 7026],
#  511: [2684, 3408, 4129],
#  516: [2540, 2543, 2846, 3296, 3377, 3811, 4888, 5261, 5909, 6482],
#  519: [1023],
#  523: [1102, 2425, 3078, 5026, 5027, 6486, 6487],
#  526: [1902],
#  527: [621,
#   943,
#   977,
#   997,
#   1251,
#   1473,
#   1559,
#   1770,
#   1826,
#   2231,
#   2336,
#   2365,
#   2927,
#   3030,
#   3423,
#   3554,
#   4139,
#   4172,
#   4256,
#   4257,
#   4271,
#   4315,
#   4789,
#   4852,
#   5140,
#   5158,
#   5162,
#   5203,
#   5690,
#   5743,
#   6059,
#   6457,
#   6460,
#   6528,
#   6551,
#   7065,
#   7099],
#  528: [631,
#   830,
#   1453,
#   1454,
#   1802,
#   2296,
#   2995,
#   3164,
#   4873,
#   4874,
#   4884,
#   4886,
#   5405,
#   5712,
#   6785],
#  538: [722,
#   1253,
#   2116,
#   2312,
#   2779,
#   2838,
#   3482,
#   3659,
#   3677,
#   4349,
#   4795,
#   4960,
#   5066,
#   5352,
#   5740,
#   5804,
#   5826,
#   7125],
#  540: [1137,
#   1214,
#   1831,
#   1875,
#   1962,
#   2193,
#   2426,
#   2914,
#   3672,
#   4018,
#   5153,
#   5315,
#   6223],
#  544: [2070, 6531],
#  546: [6111, 6118, 6340],
#  557: [1168, 2833, 3237, 3777, 4441, 4744, 4837, 4838, 5368, 5378, 6386, 6768],
#  559: [5589, 6741],
#  563: [766,
#   791,
#   792,
#   851,
#   1063,
#   1164,
#   1766,
#   2602,
#   2787,
#   2811,
#   2940,
#   3032,
#   3057,
#   3107,
#   3324,
#   3725,
#   3803,
#   3986,
#   4058,
#   4067,
#   4892,
#   4989,
#   5896,
#   6138,
#   6507,
#   6803,
#   7104,
#   7120],
#  564: [1842, 4084, 4195, 4546, 5202],
#  565: [2821, 4205],
#  566: [2823],
#  568: [570, 3432, 4876, 4881],
#  572: [702,
#   1143,
#   1381,
#   2826,
#   2858,
#   3208,
#   3887,
#   3940,
#   4366,
#   4433,
#   4942,
#   5665,
#   6690,
#   7144],
#  575: [702, 1143, 1381, 2858, 3208, 4433, 5665, 7144],
#  576: [581,
#   1570,
#   1711,
#   2658,
#   2710,
#   2894,
#   3031,
#   3382,
#   3385,
#   3487,
#   3959,
#   4047,
#   4347,
#   4484,
#   4543,
#   5018,
#   5089,
#   5319,
#   5505,
#   5699,
#   6176,
#   6575,
#   7032,
#   7058,
#   7092],
#  579: [627, 1189, 2038, 5749, 6061],
#  591: [662, 1791, 5358],
#  596: [1133,
#   3259,
#   3483,
#   3543,
#   4096,
#   4386,
#   4417,
#   4594,
#   4820,
#   5195,
#   5484,
#   5787,
#   6403,
#   6818,
#   6880,
#   6918],
#  598: [2263],
#  599: [1871, 4251],
#  600: [847,
#   868,
#   1727,
#   2311,
#   2621,
#   2859,
#   3012,
#   3314,
#   4218,
#   4625,
#   5187,
#   6260,
#   6896],
#  607: [1661, 2758, 3033, 3213, 4513, 4602, 5970, 6416, 6428, 6669],
#  610: [887, 2945, 3636, 5159, 5305, 6679, 6973, 7076],
#  615: [1507, 2972, 3304],
#  617: [4133],
#  620: [2301],
#  628: [701, 1253, 2761, 2764, 4171, 6685],
#  633: [4656],
#  638: [786, 1808, 2192, 3644, 4875, 6848],
#  639: [1518, 1594, 3226, 3285, 3357, 3579, 3736, 4813, 6812],
#  642: [732,
#   1146,
#   1240,
#   2133,
#   2595,
#   4405,
#   4652,
#   4824,
#   4980,
#   5137,
#   5491,
#   5984,
#   6325],
#  646: [4563],
#  653: [2881, 4836],
#  654: [705,
#   897,
#   1004,
#   1170,
#   1427,
#   2009,
#   2303,
#   2987,
#   3401,
#   3444,
#   3569,
#   3706,
#   3878,
#   3879,
#   3988,
#   4012,
#   4039,
#   4108,
#   4234,
#   4327,
#   4421,
#   4544,
#   4553,
#   4858,
#   4937,
#   5191,
#   5194,
#   5311,
#   5433,
#   5515,
#   5739,
#   5788,
#   6268,
#   6314,
#   6432,
#   6433,
#   6597,
#   6740,
#   6835,
#   7141,
#   7149],
#  655: [4021],
#  658: [1398, 1979, 4588, 6398],
#  664: [895, 1067, 2306, 2370, 3246, 3702, 3847, 4532, 4863, 6791],
#  671: [1285, 4063, 5222],
#  674: [687, 1526, 1723, 2897, 3136, 4444, 4751, 6905],
#  676: [3612, 4764, 5390, 5701, 6136, 6239, 7086],
#  677: [924,
#   1710,
#   2611,
#   2827,
#   2875,
#   3989,
#   4489,
#   4526,
#   4841,
#   4843,
#   5473,
#   5816,
#   5883,
#   6028,
#   6056,
#   6151,
#   6954,
#   7160],
#  678: [1789],
#  680: [3506, 4810, 5136, 5230, 6254, 6288],
#  685: [3555],
#  689: [2484, 2597, 2637, 3735, 5903, 5976],
#  694: [739,
#   814,
#   894,
#   964,
#   1595,
#   1866,
#   2443,
#   3074,
#   3122,
#   3561,
#   4127,
#   4301,
#   4310,
#   4758,
#   5117,
#   5406,
#   5725,
#   6072,
#   6158,
#   6159,
#   6601,
#   6976],
#  695: [1583, 1996, 4735, 5995],
#  697: [1336, 3103, 4558, 5071, 5979],
#  698: [937,
#   980,
#   1534,
#   3418,
#   4549,
#   4728,
#   4939,
#   5818,
#   5887,
#   5892,
#   6290,
#   6621,
#   6727,
#   6784],
#  699: [4291],
#  708: [1036,
#   1418,
#   1497,
#   1500,
#   1501,
#   1505,
#   1506,
#   1511,
#   1513,
#   1514,
#   1516,
#   1517,
#   1527,
#   1532,
#   1569,
#   1891,
#   2331,
#   2359,
#   2360,
#   2569,
#   2645,
#   4448,
#   4685,
#   5458],
#  709: [3896, 6338],
#  710: [1940, 2251, 2517, 2628, 3278, 3295, 3540],
#  724: [727, 729],
#  726: [901,
#   1629,
#   1672,
#   1781,
#   2091,
#   2769,
#   2900,
#   3562,
#   3630,
#   5307,
#   5370,
#   5477,
#   5539,
#   5981,
#   6567,
#   6825],
#  728: [1334, 3316, 4815, 4959, 4967, 5039, 5971],
#  737: [1661, 2627, 2758, 4513, 4602, 5970, 6354, 6416, 6428, 6669],
#  742: [939, 1206, 1349, 1767, 1769, 1926, 2122, 5029, 5765, 6624],
#  744: [1850],
#  745: [4610, 4744, 5186, 5378],
#  749: [810, 1194, 2849, 3979, 4517, 5948, 6395, 7038],
#  754: [5389],
#  758: [989, 1718, 1930, 3075, 3083, 3195, 3360, 3606, 4422, 5975, 6109],
#  760: [2107, 3044, 3366, 3446, 5731, 5923, 6594, 7146],
#  762: [3209],
#  764: [1611, 2010, 2475, 2792, 6789],
#  771: [1374, 1716, 1936, 2158, 3618, 3953, 4074, 4268, 6227],
#  772: [1414,
#   3102,
#   3144,
#   3448,
#   4201,
#   4462,
#   4485,
#   4644,
#   5001,
#   5773,
#   7019,
#   7128,
#   7135],
#  778: [5093],
#  779: [5221, 5623, 6761],
#  781: [785],
#  789: [866,
#   918,
#   1054,
#   1281,
#   1761,
#   2101,
#   2104,
#   2105,
#   2195,
#   2408,
#   2493,
#   2559,
#   3242,
#   3293,
#   3294,
#   3370,
#   3624,
#   3892,
#   4145,
#   4535,
#   4603,
#   4907,
#   5260,
#   5445,
#   5536,
#   5644,
#   5681,
#   5682,
#   6081,
#   6350,
#   6374,
#   6451,
#   6646,
#   6717,
#   6862,
#   6890],
#  795: [2334],
#  805: [2523, 2727, 5276, 5450, 5936, 6724],
#  806: [1174,
#   2073,
#   3317,
#   4346,
#   4352,
#   4361,
#   4368,
#   4739,
#   4741,
#   4743,
#   4748,
#   4752,
#   4757,
#   5078],
#  809: [4648, 6867],
#  817: [831, 1379, 2202, 2668, 2903, 4102, 4222],
#  833: [4614, 4632, 4634, 4887, 6548, 7004],
#  836: [1052,
#   1114,
#   1746,
#   2257,
#   2361,
#   2396,
#   2413,
#   2924,
#   2957,
#   3069,
#   3400,
#   3971,
#   4426,
#   4742,
#   4787,
#   5513,
#   5558,
#   5632,
#   5858,
#   5904,
#   5912,
#   6088,
#   6540],
#  837: [1639, 2240, 2447, 3424, 5166, 5328, 6584, 6656, 7091, 7162],
#  839: [1976, 3257, 4280, 5998, 7137],
#  850: [3301],
#  855: [1652],
#  857: [3080, 5286, 5830, 5886],
#  859: [2672],
#  860: [2688, 3608, 4796, 5595, 6636],
#  865: [1241, 1263, 3066, 4048, 4059, 4990, 5004, 6214, 6512, 6609],
#  867: [3080, 5286, 5830],
#  874: [1221, 1258, 2180, 4134, 6262, 6281, 6353],
#  878: [1488,
#   1530,
#   1810,
#   2083,
#   2662,
#   2869,
#   3481,
#   3629,
#   3765,
#   4009,
#   4013,
#   4600,
#   4839,
#   4924,
#   5557,
#   5568,
#   5637,
#   6827],
#  882: [2242, 2701, 3634],
#  885: [1934, 4320],
#  898: [2496, 4585, 6738],
#  900: [5649, 5968],
#  915: [1004,
#   1170,
#   3401,
#   3569,
#   3879,
#   3988,
#   4039,
#   4234,
#   4327,
#   4421,
#   4858,
#   5194,
#   5515,
#   6268,
#   6314,
#   6433,
#   6835],
#  922: [1953, 2189, 3596],
#  925: [1336, 1655, 2678, 3103, 5071, 5979],
#  929: [1018, 1020, 1028, 1834, 2144, 2968, 4165, 5036, 5380, 6106, 6108, 6228],
#  950: [2419, 5075, 6337, 7001],
#  954: [2686, 2824, 5871],
#  955: [992, 2469],
#  956: [985, 4503],
#  961: [4129],
#  968: [4620],
#  970: [6293],
#  972: [2761, 6685],
#  975: [5195, 6403, 6818],
#  988: [994,
#   1010,
#   1145,
#   1153,
#   1363,
#   1894,
#   2616,
#   2889,
#   3303,
#   3412,
#   3415,
#   3417,
#   4306,
#   4530,
#   4885,
#   4978,
#   5356,
#   5802,
#   6193,
#   6915,
#   7027,
#   7029,
#   7040],
#  991: [1613, 1657, 2056, 2882, 6467],
#  993: [2161, 3186, 3783, 4030, 4276, 4730, 5763, 6397],
#  1006: [1543, 2976],
#  1008: [1103, 1450, 2322],
#  1009: [2344],
#  1012: [2663, 3716, 4198, 5377, 5939, 6006, 6578],
#  1014: [4614, 4632, 4634, 4887],
#  1015: [3640, 3794, 4217, 4768],
#  1016: [1924, 2931, 4132],
#  1019: [1020, 1028, 5072, 5716, 6106, 6108, 6228],
#  1026: [3699, 3942, 4176, 5726, 6078, 6182, 6691, 6852],
#  1029: [2501, 2598, 3159, 5002],
#  1035: [1081,
#   1857,
#   2103,
#   2471,
#   2604,
#   2631,
#   3510,
#   3791,
#   3853,
#   5061,
#   6188,
#   6461],
#  1037: [1311, 6753],
#  1040: [3273, 3365, 5664],
#  1041: [1389, 2297, 3731, 6822],
#  1050: [1803,
#   2837,
#   3935,
#   4420,
#   4439,
#   4589,
#   4911,
#   4948,
#   5235,
#   5620,
#   5856,
#   5940,
#   6205,
#   6412,
#   6943],
#  1053: [4588],
#  1056: [2808],
#  1065: [2266, 2753, 4793],
#  1071: [2123, 6683],
#  1072: [1689,
#   1758,
#   2577,
#   2579,
#   2977,
#   3467,
#   3567,
#   3994,
#   4049,
#   4148,
#   5316,
#   5466,
#   5741,
#   5944,
#   6826,
#   6945],
#  1077: [1203, 1280, 2326, 2741, 3276, 3899, 6110, 6241, 7070],
#  1084: [1389, 1627, 1880, 1937, 2297, 2496, 2754, 2766, 5325, 6611, 6822],
#  1086: [4180, 4413, 6962],
#  1088: [2797, 7068],
#  1098: [3269, 4705, 4707, 5748, 6049, 6524],
#  1100: [2418, 2738, 2877, 3846, 5612, 6128, 6992, 7074],
#  1101: [2138, 2464, 3611, 5500, 6286],
#  1105: [1859],
#  1106: [1399, 2796, 4687, 6610],
#  1107: [1121],
#  1113: [3790, 5443],
#  1118: [2309, 2800, 2943, 2944, 3036, 3494, 5173, 5861, 6015],
#  1120: [1528, 4244, 4624, 4805, 5171],
#  1123: [2589, 2976, 3771, 3789, 4901],
#  1125: [2722, 3206, 3734, 4056, 4169, 4340, 5677, 6261, 6564, 6864],
#  1127: [2613, 3116, 4467, 6479],
#  1130: [1455],
#  1135: [4449],
#  1139: [4466],
#  1144: [2907],
#  1157: [1695, 3168, 4115, 6802],
#  1160: [1543],
#  1161: [2267, 3072, 4144, 5658, 5661, 5672, 5675, 5676, 5683, 5684],
#  1162: [5974],
#  1163: [4186],
#  1165: [6249, 6283],
#  1179: [5294, 6283],
#  1181: [2928],
#  1204: [4495],
#  1210: [2896, 5271],
#  1211: [1215, 1216, 1217, 1220],
#  1218: [1893, 2405, 3318, 4069, 4151, 6431, 7119],
#  1222: [1242, 2249, 6613],
#  1264: [3254],
#  1266: [2455, 3149, 3192, 3495, 3859, 5506, 6126, 6586, 7107],
#  1275: [4791],
#  1277: [2501, 2598, 4492, 4779, 6139],
#  1284: [2091],
#  1290: [2035, 4551, 5805, 6860],
#  1296: [1974, 3893, 4588, 6398, 6593],
#  1304: [1389,
#   1520,
#   1937,
#   2297,
#   2754,
#   3546,
#   3799,
#   4585,
#   4679,
#   5954,
#   6048,
#   6079,
#   6211,
#   6273,
#   6437,
#   6667,
#   6822,
#   6908,
#   6928],
#  1310: [3526, 3658],
#  1314: [4044, 4225],
#  1316: [1413, 2458, 2614, 2673, 3047, 3815, 3999, 4446, 5118, 5617],
#  1331: [1524, 1606],
#  1338: [1482, 4251, 5314, 5404],
#  1340: [1367, 3240, 4318],
#  1344: [2454, 2525, 2906, 3821, 4482, 5563],
#  1347: [5036, 5461, 6106],
#  1352: [1397, 2566, 2755, 4034, 4320, 4522],
#  1365: [2937],
#  1373: [3156, 6040],
#  1375: [2153, 2366],
#  1383: [1581, 5605],
#  1385: [1925, 3927, 6270],
#  1387: [2807],
#  1404: [4965],
#  1406: [2860, 6773],
#  1408: [1628,
#   2125,
#   2216,
#   2905,
#   3005,
#   3295,
#   3540,
#   3741,
#   3836,
#   5593,
#   5745,
#   6089,
#   6192,
#   6887,
#   6899],
#  1411: [1416, 3852, 5249],
#  1419: [2891, 4727, 4771, 5277, 6101],
#  1434: [1582, 2257, 2459, 4497, 5210, 5696],
#  1437: [5706, 5707, 5711],
#  1469: [4317],
#  1477: [5242, 7059],
#  1490: [2281, 2750, 3036, 5173, 6015, 6082],
#  1491: [2688, 3608, 4323, 4796, 5595, 7094],
#  1492: [1741,
#   2115,
#   2250,
#   2292,
#   2632,
#   2925,
#   3560,
#   3607,
#   3667,
#   5037,
#   5120,
#   5346,
#   6695,
#   6854],
#  1493: [1914, 2424, 2742, 3829, 5020, 5113, 5630, 5806, 7073],
#  1495: [5047, 6708],
#  1502: [1592, 4905, 6133, 6137, 6144, 6605],
#  1509: [2262],
#  1510: [5920],
#  1515: [3354, 6587],
#  1519: [1521, 2982, 4452, 5778, 6242],
#  1535: [1952, 3436, 3917, 4091, 4708, 4782],
#  1536: [4265, 5323, 6024, 7113],
#  1541: [5977],
#  1547: [2791, 3323, 3441, 5820, 6162, 7011],
#  1550: [2503],
#  1557: [2314],
#  1561: [3773, 4083, 4328, 4330, 4506, 4894, 6481, 6532, 6804, 6872],
#  1573: [1783, 3500, 4460],
#  1579: [1984, 2898, 5181],
#  1588: [1966, 2369, 3925],
#  1596: [5384],
#  1597: [2526,
#   2876,
#   4006,
#   4416,
#   4627,
#   4631,
#   4934,
#   5053,
#   5086,
#   5304,
#   5520,
#   5798,
#   6173,
#   6405,
#   6996],
#  1604: [6549, 6843, 6939],
#  1608: [3892],
#  1620: [1661, 2758, 3033, 3213, 4513, 4602, 5970, 6354, 6416, 6428, 6669],
#  1630: [3524, 3838],
#  1641: [4367, 5041, 6125, 6572],
#  1645: [5779, 6840],
#  1649: [2655],
#  1654: [2118, 6418],
#  1669: [3186],
#  1682: [3678, 3679, 5462],
#  1683: [2318],
#  1685: [4712, 6797],
#  1693: [3982, 4189, 4277, 4935, 6583],
#  1699: [2546, 2555, 4987],
#  1721: [1788, 4291, 5503],
#  1725: [3422, 5398, 6871],
#  1729: [4219],
#  1736: [1739, 3442, 5824, 6832, 7161],
#  1750: [3830, 5190, 5206, 5252, 5257, 5268, 6634, 6994],
#  1772: [2896, 4354, 4845, 5271, 5652, 6057],
#  1773: [2557, 6672],
#  1790: [1803,
#   2227,
#   4420,
#   4439,
#   4589,
#   4911,
#   4948,
#   5235,
#   5620,
#   5856,
#   5940,
#   6412,
#   6943],
#  1798: [3700, 6361],
#  1801: [5285, 5864, 6140, 6390],
#  1822: [2703, 6705],
#  1855: [3486, 5521, 5755, 6318],
#  1872: [6885],
#  1878: [2098, 2778, 4029, 4584],
#  1884: [1887],
#  1886: [4094, 4961, 6358],
#  1888: [4916],
#  1913: [2086, 2139, 2162, 2201, 2560, 3157, 4216, 6032],
#  1931: [4846, 7147],
#  1943: [1951],
#  1950: [6518],
#  1964: [2349],
#  1975: [2551, 6203],
#  1980: [4617],
#  2001: [2607, 4504, 5398],
#  2003: [3650],
#  2011: [2322, 4199],
#  2024: [4993],
#  2041: [2046,
#   3747,
#   3760,
#   4241,
#   4243,
#   4437,
#   6493,
#   6496,
#   6517,
#   6541,
#   6546,
#   6547,
#   6816],
#  2063: [5095, 6381, 6889],
#  2068: [3455],
#  2089: [3767, 3863, 5993, 6183],
#  2096: [5902],
#  2108: [2114],
#  2111: [2446, 2700, 6212],
#  2124: [2713],
#  2127: [2576, 4146, 4383, 5622, 6645],
#  2142: [2865, 5549],
#  2150: [3460, 4541, 6182, 6852],
#  2157: [2336,
#   2777,
#   3030,
#   3423,
#   3554,
#   4789,
#   4897,
#   5140,
#   5162,
#   5413,
#   6059,
#   6460],
#  2159: [6265],
#  2165: [2582, 5730],
#  2171: [5326, 5855, 7045],
#  2187: [6122],
#  2190: [6256, 6259],
#  2196: [6339, 6684],
#  2208: [6766],
#  2209: [2299],
#  2214: [4438, 4826, 5096],
#  2217: [3260],
#  2224: [7017],
#  2225: [2795],
#  2256: [6217],
#  2260: [3989, 5883, 6954],
#  2261: [2348],
#  2270: [2532, 3114, 3123, 3480, 3544, 4447, 4865],
#  2273: [4449],
#  2276: [4097, 4098, 5541],
#  2277: [2440, 6416],
#  2279: [2341, 2358, 4105, 4106, 4107, 5770, 6388],
#  2293: [3267, 3947],
#  2315: [2546, 4957, 5800],
#  2320: [2350, 2747],
#  2321: [4295, 4305],
#  2328: [5374],
#  2330: [3969, 6175],
#  2339: [2448, 2465, 5324],
#  2343: [7103],
#  2345: [3865, 3889, 3906, 5571],
#  2356: [3264, 3793],
#  2362: [2470],
#  2376: [5294],
#  2412: [4653, 4749, 5402, 5516, 5634, 6565],
#  2428: [4213, 4331],
#  2449: [3399, 5962, 6202, 7062],
#  2482: [5284],
#  2487: [3108, 3761],
#  2489: [3784],
#  2497: [4918],
#  2498: [2794, 6508],
#  2504: [3055, 4046, 4253, 5540, 5625, 6073],
#  2515: [5937],
#  2538: [5282],
#  2549: [4679, 5057],
#  2561: [2583, 2636, 5188],
#  2570: [4088],
#  2591: [5345],
#  2593: [4109, 5862],
#  2608: [2690, 5250, 5643],
#  2647: [4966],
#  2651: [2759, 6044],
#  2661: [3910],
#  2669: [2671, 2724],
#  2682: [4551, 5805, 6860],
#  2685: [4359],
#  2698: [3137],
#  2705: [4393, 4431, 5526, 5688, 6823],
#  2739: [4204, 5660, 5679, 6793],
#  2751: [3591, 6533, 6538],
#  2767: [5080, 5133, 7018],
#  2810: [3578],
#  2816: [5508],
#  2831: [3034],
#  2834: [5769],
#  2841: [5009, 6197],
#  2843: [3491, 4092, 5366, 6042, 6857],
#  2863: [3733, 4192, 7036],
#  2868: [4495],
#  2885: [2887],
#  2921: [2923, 6022, 6618, 6935],
#  2936: [2938, 2939, 3943, 4071, 4811, 6787, 7157],
#  2947: [5294],
#  2966: [5452, 5917],
#  2985: [5234],
#  2988: [3201, 3955, 5353],
#  2992: [5391, 6746],
#  3010: [3185, 3193, 5794],
#  3067: [5847],
#  3071: [5645, 5853],
#  3077: [4531],
#  3089: [4023, 7119],
#  3095: [5253, 6886],
#  3139: [6682],
#  3152: [5913],
#  3167: [4988, 5456],
#  3173: [6036, 7089],
#  3180: [6367],
#  3182: [3787, 5038],
#  3205: [3478],
#  3215: [5671],
#  3228: [4367, 5041, 6125],
#  3238: [3321, 4724, 6813],
#  3243: [4372, 6982],
#  3245: [4283],
#  3255: [3872, 3997, 4516, 4524],
#  3287: [3456, 3840, 3851, 3967, 4264, 4394, 4458, 4528, 5013],
#  3290: [5809],
#  3305: [6522, 6523, 6525, 6891],
#  3320: [3718, 3936, 4668, 6772],
#  3328: [3842, 3988, 4858, 5515],
#  3339: [3705],
#  3341: [3922],
#  3344: [6189],
#  3372: [5174],
#  3383: [3892, 5644, 6081, 6515],
#  3395: [3416],
#  3410: [3657],
#  3425: [3958, 4542, 5480],
#  3428: [6122],
#  3447: [5236],
#  3469: [5005, 5033, 5504, 6714, 7083],
#  3475: [6050],
#  3477: [4691, 5550, 5867],
#  3498: [3843],
#  3534: [5102, 6441],
#  3568: [4196],
#  3610: [6163],
#  3615: [4303, 5036, 6448, 6462],
#  3621: [3649, 4028, 4773],
#  3633: [6841],
#  3665: [6710],
#  3673: [5225],
#  3740: [6313],
#  3762: [5292],
#  3769: [5301],
#  3801: [4932, 5272],
#  3832: [4847, 6077, 6252],
#  3869: [3951],
#  3881: [6683],
#  3888: [4103],
#  3903: [4395, 5922],
#  3905: [5465],
#  3945: [5392],
#  3965: [4027, 4060],
#  3974: [6940],
#  3984: [4251],
#  3987: [5452, 5917, 6164],
#  4001: [7009],
#  4008: [5958],
#  4037: [4251],
#  4135: [5497],
#  4170: [4901],
#  4210: [4818],
#  4230: [6484],
#  4245: [4556, 6953],
#  4272: [5532],
#  4281: [4708, 4782],
#  4300: [4508],
#  4302: [4309],
#  4332: [4334],
#  4333: [6754],
#  4424: [6856],
#  4445: [5883, 6954],
#  4478: [4769],
#  4490: [5318, 5619, 6156, 6889],
#  4525: [5151],
#  4552: [4916],
#  4640: [4643],
#  4646: [4910],
#  4670: [5899],
#  4745: [6681],
#  4753: [6584],
#  4794: [5337, 6963],
#  4828: [7122],
#  4870: [6863],
#  4926: [5317, 5694, 5911, 6083, 6466],
#  4940: [6370],
#  4994: [5147, 6071, 6217, 7155],
#  5048: [5216],
#  5074: [5454],
#  5119: [6078],
#  5123: [5589],
#  5198: [5705],
#  5237: [6036],
#  5258: [6782],
#  5537: [5648, 5812, 5897],
#  5555: [6187],
#  5561: [6145],
#  5583: [6986],
#  5597: [5715],
#  5626: [6758],
#  5667: [5670, 7053],
#  5758: [5759],
#  5762: [6975],
#  5768: [6919],
#  5842: [7097],
#  5874: [7048],
#  5928: [7143],
#  5938: [5949],
#  5973: [6005],
#  6120: [6316, 6706],
#  6178: [6800],
#  6277: [6855],
#  6307: [6836],
#  6328: [7057],
#  6334: [6676],
#  6363: [7129],
#  6488: [6491],
#  6641: [6723],
#  6718: [7038],
#  6767: [6888]}

# %%
# set all remaining activities without a cluster assignment to a new a activity key
mask1 = df['activity_id'] == 0
cluster_center_idxs = np.concatenate((np.argwhere(df['activity_id'] == 0).ravel(), np.array(final_clusters.keys())))
df.loc[mask1, ['activity_id']] = df.loc[mask1, ['activity_id']].apply(lambda x: uuid.uuid4().hex[:8], 1)
cols = ['map_summary_polyline', 'start_lat', 'start_lng', 'end_lat', 'end_lng', 'activity_id']
df.loc[cluster_center_idxs, cols]
# Out:
#                                    map_summary_polyline  start_lat  start_lng  \
# 7     _t_sFf|h`SXmIqBQjB^BdFZsNpGcN_HdOm@jPbp@}@ap@~...      39.98    -105.07
# 9     opdsFxjlaSO`CaIzAq@`g@sDp@ErP_VaFq\o@eAiF}@zEw...      40.01    -105.25
# 10    esrqFjuj_SxXJ@qFld@e@~xAA~BbDvZ`AbKeFnAzE@h^zh...      39.75    -104.92
# 12    sjnoF|r{`S[iEeCbBwFoF~AkDyAuIk@tDgBcDaIfCtCkFq...      39.40    -105.17
# 18                                       _s{sFnqs~Rh@c@      40.12    -104.80
# 40    ubwpFvif_SuC}vBmcCi@eHfKmq@mOoS{N{l@arAwFoYsI}...      39.61    -104.90
# 46    a_upFfxbiS~_Bkb@_AnBoDFwQ`KyIeCoMnBaXfOgg@h@eI...      39.60    -106.52
# 68    e`qsF`~gbSfMtTrC~b@xPdW_b@`RcDpFBzJsYaAcHfGlFv...      40.07    -105.40
# 80    kfjlFtiblSuM|GqCoA}GpEoEi@oBtAmDlJWfLlAzAm\nj@...      38.89    -107.00
# 82    }arnFlvciSpZuCs@fBdGrH~AFw@mC`AcF}@iBbEqDwCqAk...      39.26    -106.52
# 86      _huqF|_s_Sn@vDbFJOtnAlhAd~AsKnOuJyN`BiDt@nAs@iB      39.76    -104.96
# 87    e_|pFdb`bSvSfBcC}HwAoOhMtC|E|Ee@}N{HAeAuBPiCtB...      39.63    -105.35
# 100   yfcqFvn{`S~EaE|f@yExLoKnAaG~CwCfMdS`KxGyLuKgLg...      39.67    -105.17
# 102   }lcqF~st_SpY`AXoDDshBnCoMaCkOK}^iCuEpD_Vq@c~Aw...      39.67    -104.97
# 104     _|uvF`|i`S`@cGjAiAbcAOVwu@rSIZeM~DgXqBcETk[hGeA      40.59    -105.08
# 112   ernpFhkc`SIvQdH~A|G`LfApTpLpa@D|UmIb`@fKhYtYb]...      39.57    -105.04
# 115                              {{vsF~draSv@sGd^?k_B{A      40.10    -105.28
# 123   _ufsF~}paSxGnk@oAtRjG|j@oBt@jCvHxD~AkCbUzHzL]j...      40.02    -105.28
# 139   _fksFx{naSiC|DnDqGFiQzKQm@uHzAgAbWiB`AoE|DkAlA...      40.04    -105.27
# 144   coxqFnoe_S`FqASqV|AaZb_@p@hGvFvDtHmPlReGhVoHG@...      39.78    -104.89
# 145   ooieFztipSwe@hP~AjLaUjVrWpf@mZ`OtNzXbArf@}s@mh...      37.74    -107.70
# 146   a}{rFnxz`S{z@wAuZdNqp@AqTeIjAboHq`Cs@yo@vDHbfB...      39.96    -105.16
# 147   _zvqFvyaeSNnIoGrM_BrJgTjQ_O[kBxDmh@bKmAzIqDlDm...      39.77    -105.86
# 150   ibpqF~et_SDjp@lIb@RrZnyAhAoAnjBvN^JhVzi@sHExKl...      39.74    -104.97
# 152   onmsFxxraSxNNPpHnFdJuBrBD`E~HxGxFcAjHmFbC_GfJv...      40.05    -105.29
# 171   ikesFlbnaSn@rH~DZlW|Stx@p@oDJnA~[jPfDhNpWpTzSp...      40.01    -105.26
# 187   ea~uF~zyjSGxD|IzOtAxObDtEzAnIjCnA\nNjCnHaAjQhA...      40.46    -106.80
# 188   sljuFdk`cSw@CrAEnDwHAtE~CGe@tFhG_BcAk@mDvCPiG{...      40.36    -105.52
# 199   qjgrFxud`S?oEnHkA`BiTbD{EdEiRpOhGlGtHrZiXnDsHb...      39.86    -105.05
# 201   cijqFbmnaSwRjFoD|CuCjNzDpPqDzDqDScAmLz@aG}AsNh...      39.71    -105.26
# ...                                                 ...        ...        ...
# 5123  {wopF~`j`SPtBmBuDbBsCqCqFIeZmEsWf@gYwDaYvIiRf[...      39.57    -105.08
# 5198  y|wmFjgj_SdJbGg@`YhF`XPtHzAv@tB|HGjJxBvBbB~QhB...      39.12    -104.92
# 5237  ydbsF|dn`SxAdByGzB@nj@~TbFhKnMBvJ}EbJsQ|JcFtIk...      39.99    -105.10
# 5258  }tzqFz}u`Sn@x{E~XzAQpUgBdMIzq@r}@~KvIfCvLzLlJl...      39.79    -105.14
# 5537  g_jpFxq`_Sk@iA_K~@uSaQ}AkLmD}Im@wMr@eHhEoErWkE...      39.54    -104.87
# 5555  {~clFlp`_S`FhBjj@cjAxCo@s@}u@~H_FGcSfFHaAqLnAs...      38.86    -104.87
# 5561  wxalFbu{~RsEe@ExSiIvE|@z}@gLdTkC_ByAvAg\bp@gEk...      38.84    -104.84
# 5583  awerFly`bS_Fp@cKbJa@~GeAz@iDeK^sF{@oE}G{K{KqHE...      39.85    -105.36
# 5597  {}asFzbhaSoRFcFvY_b@d@cF|KqKlGnGdSGz|@goC`BdBk...      39.99    -105.23
# 5626                               kvtpFbnedSp@GeBEpAbB      39.60    -105.71
# 5667  ifaqF~aq`SkA}F{Jm@QrEhEjEa@|W|KdJuSbKtClVbPxHd...      39.66    -105.11
# 5758                                   y}xlFvhj~Rz@I[t@      38.96    -104.75
# 5762  {csqFdcg`SiBkhBjJeVAkzC_Quy@~e@mk@tj@kLlkAwx@t...      39.75    -105.06
# 5768  oeuqFdme_S~{@b@dH}BrDnHhSLz@fk@hkBDbB~IdU~Ap@j...      39.77    -104.89
# 5842  moapF|gg~RMkJcCSK_HfKoJfArBFoGeDsAiH|BgHxDoCpE...      39.50    -104.74
# 5874  adhqFtqk_Sw@mA~]}t@vE]hp@crA~\_WxDnF~QSdFmBfAw...      39.70    -104.92
# 5928  wtjeF~plpSmH`RgMq@lNxWdAtg@{s@ih@}tAvj@l@vp@l[...      37.74    -107.71
# 5938  wxduFlex`SxQg@goB?s@jR}AjCqx@Cc@bBt@yA~w@BbBkC...      40.33    -105.15
# 5973  sksqF~_}_SiEaMnEzF~Mdj@D|gCcV~Aj@xsQ{DjHTnb@gg...      39.75    -105.01
# 6120  o|~qFvw}`SRfyAzaAg@~Ve`@|VgDjOvAzG|Fzo@~Cti@zK...      39.81    -105.18
# 6178  g}jqF~|w_S}CsFsTs@YiMko@nA|Qw]`Gs\{@vDaHaAk@{e...      39.71    -104.99
# 6277  qtqlF|du~REfMiBpDoB_CyIaBwIlGkLm@^aMeCiD^xBwC[...      38.93    -104.81
# 6307  {dmqFrnq`SgE{@g@oFrD{@rNzh@nFrDlW_N|k@{@?v[r]?...      39.72    -105.12
# 6328  {f|pFh_diSq@bDxZr@jFwWra@eyAvHwiANa~@|JwtAxKyS...      39.64    -106.52
# 6334  ofejFxp|eS_MyJe_@~e@sHt_AkXcBuQh[q}@gBKghAcs@x...      38.53    -105.99
# 6363  shsvFtxu`SFyCdJcEBiN`pBq@y@mvBl@quIzCwQiCwRQu|...      40.57    -105.14
# 6488  qg|pF`kqaSc@|Lf@yKiBqAsPxLqCxJwD|CyCqDYsClIs\e...      39.64    -105.28
# 6641  }kvuFrcq`S@tA{BMMhE~Y_@ve@mTV~|AYdBgMnFQ|Gz[k@...      40.42    -105.11
# 6718  ku{qF|bcaShDg^dG_P|SyO`KgDdU_B`HfC`IsKxIkDxPbC...      39.80    -105.21
# 6767  _mcoFreraScAzIoEuAyBjDMhFaDqEwENa@jI_DNKrGyBRt...      39.34    -105.28
#
#       end_lat  end_lng activity_id
# 7       39.98  -105.07    ef76e465
# 9       40.00  -105.30    d82a9a83
# 10      39.75  -104.94    ac408b14
# 12      39.40  -105.17    84efc94f
# 18      40.12  -104.80    180c0021
# 40      39.73  -105.00    166f39db
# 46      39.60  -106.52    7f312c8b
# 68      39.98  -105.25    69eab424
# 80      38.89  -107.00    b9be3b37
# 82      39.26  -106.52    b7876001
# 86      39.75  -104.99    e651a783
# 87      39.62  -105.36    1cdb1de4
# 100     39.70  -105.25    b044c63d
# 102     39.75  -105.00    7e2aeef7
# 104     40.57  -105.05    61cc9005
# 112     39.54  -105.00    0c5308a5
# 115     40.11  -105.28    2cc58566
# 123     40.02  -105.28    44c8cd28
# 139     40.04  -105.27    2a91d6a2
# 144     39.78  -104.89    841fc9b9
# 145     37.29  -107.88    e2af4c18
# 146     40.01  -105.23    4fc304fb
# 147     39.77  -105.85    310bc152
# 150     39.74  -104.97    76f5aace
# 152     40.00  -105.26    6b0f6792
# 171     40.01  -105.29    277855ef
# 187     40.49  -106.83    01c28f43
# 188     40.36  -105.52    d1d07b57
# 199     39.77  -105.05    32b6cd6c
# 201     39.71  -105.26    558ef11a
# ...       ...      ...         ...
# 5123    39.57  -105.08    7e6f1856
# 5198    39.12  -104.92    6ce80d67
# 5237    39.99  -105.10    3a3bf2f7
# 5258    39.79  -105.14    307f7223
# 5537    39.54  -104.86    b96fdc35
# 5555    38.84  -104.84    5453666f
# 5561    38.86  -104.87    1c92a8ec
# 5583    39.85  -105.36    cc7c3ad8
# 5597    40.06  -105.28    951e4ba4
# 5626    39.60  -105.71    bd58f25c
# 5667    39.66  -105.11    a7426fb5
# 5758    38.96  -104.75    8ae4eceb
# 5762    39.75  -105.06    9a118be6
# 5768    39.77  -104.89    6b000b64
# 5842    39.50  -104.74    0f4d95fb
# 5874    39.69  -104.95    3aad9059
# 5928    37.74  -107.71    b11f2dc6
# 5938    40.33  -105.15    0c89aabb
# 5973    39.76  -105.03    096423a3
# 6120    39.81  -105.18    0727845e
# 6178    39.71  -104.99    899eb817
# 6277    38.96  -104.79    55f17d1a
# 6307    39.72  -105.13    d0e0895a
# 6328    39.64  -106.52    5b1443a0
# 6334    38.53  -105.99    04714bd4
# 6363    40.57  -105.14    4ca70881
# 6488    39.64  -105.28    f26e03da
# 6641    40.42  -105.11    acbf6080
# 6718    39.81  -105.20    1ff303a5
# 6767    39.34  -105.28    dbfa43e1
#
# [2350 rows x 6 columns]

# %%
df.groupby(['activity_id']).count()['id'].order(ascending=False)
# Out:
# /Users/gmacmillan/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: order is deprecated, use sort_values(...)
#   if __name__ == '__main__':
# activity_id
# dd089616    231
# 93f1bb8f    129
# 9f67dc6a     82
# cb07d7be     78
# 40a18b46     65
# 86e64eab     64
# 7b88ab3f     62
# c8e8ba8d     57
# cbaef092     55
# da5714b7     54
# c7e7d05e     51
# 3b1b13c5     48
# 250e5250     47
# 35bb644f     47
# b2a97a5e     43
# d669b03a     43
# 12e99e62     43
# 595348f9     37
# c20abdd9     37
# e54cbe0c     36
# b45134e5     35
# 4b6fd133     34
# 8ea4e3f6     34
# 51daf7f2     34
# 9468eefa     31
# 46f82e94     30
# 88b8b029     30
# b1070338     29
# f56315e9     29
# f8a9dee4     28
#            ...
# a017f1ce      1
# 9b9d076d      1
# 9d792a31      1
# 9bceb274      1
# 9c1e0415      1
# 9c58a15c      1
# 9c5c8e5a      1
# 9c60ff10      1
# 9c7ecfe9      1
# 9c8fde1d      1
# 9c922ee6      1
# 9c96c7f0      1
# 9ca01fb9      1
# 9cbe4007      1
# 9d5608f4      1
# 9db6a96c      1
# 9fd55658      1
# 9dce9973      1
# 9dea4849      1
# 9e0ae457      1
# 9e469a6f      1
# 9e48fd32      1
# 9e5c9423      1
# 9ec9a1e1      1
# 9eccbb6b      1
# 9efdc6c1      1
# 9f511590      1
# 9f74ce96      1
# 9fc6aea4      1
# 00141355      1
# Name: id, dtype: int64

# %%
final_clusters[0]
# Out:
# [466, 1818, 1873, 2731, 2790, 3904, 7025]
