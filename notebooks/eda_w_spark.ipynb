# %% [markdown]
# # EDA with Apache Spark

# %%
import pyspark as ps
import random

spark = ps.sql.SparkSession.builder \
        .appName("rdd test") \
        .getOrCreate()

random.seed(1)

# %%
# Test spark using the following code..
def sample(p):
    x, y = random.random(), random.random()
    return 1 if x*x + y*y < 1 else 0

count = spark.sparkContext.parallelize(range(0, 10000000)).map(sample) \
             .reduce(lambda a, b: a + b)

print("Pi is (very) roughly {}".format(4.0 * count / 10000000))
# Out:
# Pi is (very) roughly 3.14217

# %% [markdown]
# In this notebook, I will try to explore the data I'm using to build the activities recommender. Before I go too far with the analysis, let me explain what the data is and where it is from.

# %% [markdown]
# # Strava:
#
# Strava is an activity tracker and athlete social network. It is available in mobile and web application formats. It is also available to apple watches as an addon to the standalone mobile app. Strava recently released a new feature called athlete posts which allows athlete's to update their social feeds with blog style postings on their adventures. Strava describes it's new goal as, "everything you love about your sport, in one app".

# %% [markdown]
# ## Activities:
#
# Activities in Strava are the main item's that User's get to post through the app. There are many activities you can do but for the purpose of my app, I will be focusing on just rides(cycling) and runs.

# %% [markdown]
# ## Objective:
#
# The main objective of this notebook is to explore the strava data, make some inferences about the activities and build a recommender model that will analyze and incoming user's previous strava data and output customized recommendations for activities. This model will be integrated with a Django web application for tracking and managing an athlete's recommendations online.

# %% [markdown]
# To start I will import the necessary modules:

# %%
import numpy as np # linear algebra
import pandas as pd # Data ETL, csv file I/O
import matplotlib.pyplot as plt # MATLAB like plotting framework
import seaborn as sns # statistical data vizualization library based on matplotlib

color = sns.color_palette()

# %matplotlib inline

# %%
from subprocess import check_output
print(check_output(["ls", "../data"]).decode("utf-8"))
# Out:
# act_ids_135209.csv
# act_ids_89358.csv
# activities_large.csv
# activities_small.csv
# ath_ids_1745.csv
# athletes_small.csv
# athletes_small.pkl
# colorado_cities.csv
# item_similarity_rides.npy
# item_similarity_runs.npy
# remaining_acts.csv
# rides_clusterer.pkl
# rides_mapper.pkl
# runs_clusterer.pkl
# runs_mapper.pkl
# user_similarity_rides.npy
# user_similarity_runs.npy

# %% [markdown]
# The above are files I have used to store data that I used in the building of the web application and recommender model. The files beginning with "act_id" contain activity id's I initially scraped using the [web scraping class]('../scrape_clean/scraper.py'). activities_large.csv and activities_small.csv contain rows of activity data and as indicated by them name the size is small and large: small for building and testing the model, large for actually training the production model.

# %% [markdown]
# ath_ids_1745.csv contains 1745 athlete id's from who's accounts I was planning to pull most of the data. This didn't work the way I initially intended as the Strava v3 API requires you to have the id associated with each activity in order to pull the data and the API doesn't allow you to query for activity id's simply given the athlete id. athletes_small.csv is file with profile data for a set of athlete's. This will not be used in the production app.

# %% [markdown]
# colorado_cities.csv contains a list of colorado cities and latitude/longitutde data for each that I scraped using [get_cities_wikipedia.py]('../scrape_clean/get_cities_wikipedia.py'). The rest of the files are artifacts from the previous iteration of this project (TODO: archive these files).

# %% [markdown]
# let's go ahead and take a look at the activities data:

# %%
small_df = pd.read_csv("../data/activities_small.csv", parse_dates=["start_date", "start_date_local"])
small_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9925 entries, 0 to 9924
# Data columns (total 40 columns):
# id                        9925 non-null int64
# name                      9924 non-null object
# distance                  9925 non-null float64
# moving_time               9925 non-null float64
# elapsed_time              9925 non-null float64
# total_elevation_gain      9925 non-null float64
# type                      9925 non-null object
# start_date                9925 non-null datetime64[ns]
# start_date_local          9925 non-null datetime64[ns]
# timezone                  9925 non-null object
# achievement_count         9925 non-null int64
# kudos_count               9925 non-null int64
# comment_count             9925 non-null int64
# athlete_count             9925 non-null int64
# photo_count               9925 non-null int64
# total_photo_count         9925 non-null int64
# trainer                   9925 non-null bool
# commute                   9925 non-null bool
# manual                    9925 non-null bool
# private                   9925 non-null bool
# flagged                   9925 non-null bool
# average_speed             9925 non-null float64
# max_speed                 9925 non-null float64
# average_watts             7451 non-null float64
# max_watts                 2221 non-null float64
# weighted_average_watts    2217 non-null float64
# kilojoules                7417 non-null float64
# device_watts              9925 non-null bool
# has_heartrate             9925 non-null bool
# average_heartrate         3558 non-null float64
# max_heartrate             3558 non-null float64
# athlete_id                9925 non-null int64
# map_id                    9925 non-null object
# map_summary_polyline      9832 non-null object
# start_lat                 9925 non-null float64
# start_lng                 9925 non-null float64
# end_lat                   9888 non-null float64
# end_lng                   9888 non-null float64
# state                     9924 non-null object
# closest_city              9925 non-null object
# dtypes: bool(7), datetime64[ns](2), float64(16), int64(8), object(7)
# memory usage: 2.6+ MB

# %%
large_df = pd.read_csv("../data/activities_large.csv", parse_dates=["start_date", "start_date_local"])
large_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105487 entries, 0 to 105486
# Data columns (total 40 columns):
# id                        105487 non-null int64
# name                      105477 non-null object
# distance                  105487 non-null float64
# moving_time               105487 non-null float64
# elapsed_time              105487 non-null float64
# total_elevation_gain      105487 non-null float64
# type                      105487 non-null object
# start_date                105487 non-null datetime64[ns]
# start_date_local          105487 non-null datetime64[ns]
# timezone                  105487 non-null object
# achievement_count         105487 non-null int64
# kudos_count               105487 non-null int64
# comment_count             105487 non-null int64
# athlete_count             105487 non-null int64
# photo_count               105487 non-null int64
# total_photo_count         105487 non-null int64
# trainer                   105487 non-null bool
# commute                   105487 non-null bool
# manual                    105487 non-null bool
# private                   105487 non-null bool
# flagged                   105487 non-null bool
# average_speed             105487 non-null float64
# max_speed                 105487 non-null float64
# average_watts             73269 non-null float64
# max_watts                 17008 non-null float64
# weighted_average_watts    16954 non-null float64
# kilojoules                73023 non-null float64
# device_watts              105487 non-null bool
# has_heartrate             105487 non-null bool
# average_heartrate         30209 non-null float64
# max_heartrate             30209 non-null float64
# athlete_id                105487 non-null int64
# map_id                    105487 non-null object
# map_summary_polyline      104694 non-null object
# start_lat                 105487 non-null float64
# start_lng                 105487 non-null float64
# end_lat                   105096 non-null float64
# end_lng                   105096 non-null float64
# state                     105400 non-null object
# closest_city              105487 non-null object
# dtypes: bool(7), datetime64[ns](2), float64(16), int64(8), object(7)
# memory usage: 27.3+ MB

# %% [markdown]
# Full disclosure, this is not actually the raw data format I recieved from the Strava v3 API. I already ran this data through transformer functions located in [get_cities_wikipedia.py]('../scrape_clean/setup.py'). These did things such converting data-types, parsing object types such as map and athlete for useful information and adding a state and closest city column.

# %% [markdown]
# I have already taken a look at some of the distributions from the data above in the notebook [eda_modeling.ipynb]('./eda_modeling.ipynb'). The above data is great but the spark ALS recommender model, uses data in the format:
#
# `user_id, item_id, rating (optional: date of last rating)`

# %% [markdown]
# ## Clustering

# %% [markdown]
# In order to get a ratings data to look at, I will need to run it through a custom clustering model which clusters by geographical location using latitude, longitude and google summary_polyline format. Let's see how this works. First I will create a dataframe on which to predict clusters.

# %%
df = small_df[small_df['commute'] == 0] # drop all where commute = true and store as new dataframe, df
df = df[df['state'] == 'Colorado'] # drop all where state != Colorado
df = df[df['type'] == 'Ride'] # drop everything that is not of type 'Ride' for now
df.dropna(subset=['map_summary_polyline'], inplace=True) # drop all where map_summary_polyline is nan

# %% [markdown]
# Next build training and test set. Since this is clustering, it is unsupervised, therefor there are no labels to test against. The test set is simply to test the transform method on held out or new data.

# %%
msk = np.random.rand(len(df)) < 0.75
train = df[msk].reset_index(drop=True)
test = df[~msk].reset_index(drop=True)

# %% [markdown]
# Next start the clusterer, fit it on training data, predict labels for the training set, then transform the test set:

# %%
import sys
sys.path.insert(0, '../velosparkapp/recommender/')
from clustering import PolyClusterer

clusterer = PolyClusterer()
clusterer.fit(train)
train_labels = clusterer.predict(train)
test_labels = clusterer.transform(test)

# %%
df.shape[0] == train_labels.shape[0] + test_labels.shape[0]
# Out:
# True

# %% [markdown]
# So we know the clustering outputs activity labels for all the activities. Under the covers, it actually appends the labels on to dataframe for the training set. It does not, however, do this to the test set. Another thing it will do is yield a dataframe of clusters centers.

# %%
centroids = clusterer.cluster_centers_
centroids
# Out:
#      activity_id  end_lat  end_lng  index  \
# 0       25b96643    39.98  -105.07    4.0
# 1       634541b3    40.00  -105.30    5.0
# 2       3d4e6eba    39.75  -104.94    6.0
# 3       96c5e064    39.40  -105.17    8.0
# 4       9dbdb00c    40.12  -104.80   13.0
# 5       3ac7c3ca    39.73  -105.00   29.0
# 6       f2db8536    39.98  -105.25   44.0
# 7       156d40d7    38.89  -107.00   48.0
# 8       4f2ea9ad    39.75  -104.99   51.0
# 9       272951f4    39.70  -105.25   60.0
# 10      4b83684d    39.75  -105.00   61.0
# 11      1dd87a8e    40.57  -105.05   63.0
# 12      810ac6b2    40.11  -105.28   70.0
# 13      66aba9c7    40.10  -105.28   77.0
# 14      97ccd439    39.69  -105.33   86.0
# 15      8a927392    40.04  -105.27   87.0
# 16      45df5b5b    40.57  -105.14   90.0
# 17      95341ab6    37.29  -107.88   91.0
# 18      f3c2bbf1    40.01  -105.23   92.0
# 19      54506471    38.87  -106.99  103.0
# 20      7e0259f1    40.04  -105.25  106.0
# 21      708822c4    40.49  -106.83  112.0
# 22      b16d140d    39.77  -105.05  115.0
# 23      ff886f63    39.71  -105.26  117.0
# 24      cb6f9493    39.68  -104.98  121.0
# 25      5cd4f7c3    39.69  -104.92  128.0
# 26      5ca357fc    39.77  -104.88  147.0
# 27      3185f01a    40.02  -105.26  155.0
# 28      0d0d4dd8    39.98  -105.08  162.0
# 29      9d3b8e35    39.70  -104.98  163.0
# ...          ...      ...      ...    ...
# 1951    1b35216a    40.49  -106.84    NaN
# 1952    a17a1329    39.98  -105.24    NaN
# 1953    e7cf3926    40.54  -105.09    NaN
# 1954    c3b8a042    39.86  -105.05    NaN
# 1955    c9f972a0    39.78  -105.04    NaN
# 1956    83108d50    40.46  -106.80    NaN
# 1957    32181a21    39.80  -105.08    NaN
# 1958    9c6ebe17    39.70  -104.98    NaN
# 1959    a598c2fd    39.63  -104.91    NaN
# 1960    a922bbf8    40.31  -105.20    NaN
# 1961    fe6f3ea5    40.04  -105.25    NaN
# 1962    c9f9f45b    39.70  -104.98    NaN
# 1963    050a639c    39.63  -105.16    NaN
# 1964    fd27f42d    39.72  -105.12    NaN
# 1965    e981d415    39.62  -104.90    NaN
# 1966    be1cfc92    40.07  -105.28    NaN
# 1967    7aaf1e54    40.07  -105.28    NaN
# 1968    93aba4d7    40.13  -105.28    NaN
# 1969    3cc9472b    39.62  -105.14    NaN
# 1970    5e9b619c    40.02  -105.23    NaN
# 1971    5560ed6f    38.75  -106.08    NaN
# 1972    b6ad6951    40.09  -105.94    NaN
# 1973    2e79214d    39.65  -104.85    NaN
# 1974    0ef5b2f5    39.27  -108.69    NaN
# 1975    51f42c49    40.04  -105.25    NaN
# 1976    5a99ac0b    40.03  -105.29    NaN
# 1977    107d2610    39.87  -105.24    NaN
# 1978    04240174    40.03  -105.29    NaN
# 1979    1135581c    40.04  -105.25    NaN
# 1980    2db5139b    39.72  -104.96    NaN
#
#                                    map_summary_polyline  start_lat  start_lng
# 0     _t_sFf|h`SXmIqBQjB^BdFZsNpGcN_HdOm@jPbp@}@ap@~...      39.98    -105.07
# 1     opdsFxjlaSO`CaIzAq@`g@sDp@ErP_VaFq\o@eAiF}@zEw...      40.01    -105.25
# 2     esrqFjuj_SxXJ@qFld@e@~xAA~BbDvZ`AbKeFnAzE@h^zh...      39.75    -104.92
# 3     sjnoF|r{`S[iEeCbBwFoF~AkDyAuIk@tDgBcDaIfCtCkFq...      39.40    -105.17
# 4                                        _s{sFnqs~Rh@c@      40.12    -104.80
# 5     ubwpFvif_SuC}vBmcCi@eHfKmq@mOoS{N{l@arAwFoYsI}...      39.61    -104.90
# 6     e`qsF`~gbSfMtTrC~b@xPdW_b@`RcDpFBzJsYaAcHfGlFv...      40.07    -105.40
# 7     kfjlFtiblSuM|GqCoA}GpEoEi@oBtAmDlJWfLlAzAm\nj@...      38.89    -107.00
# 8       _huqF|_s_Sn@vDbFJOtnAlhAd~AsKnOuJyN`BiDt@nAs@iB      39.76    -104.96
# 9     yfcqFvn{`S~EaE|f@yExLoKnAaG~CwCfMdS`KxGyLuKgLg...      39.67    -105.17
# 10    }lcqF~st_SpY`AXoDDshBnCoMaCkOK}^iCuEpD_Vq@c~Aw...      39.67    -104.97
# 11      _|uvF`|i`S`@cGjAiAbcAOVwu@rSIZeM~DgXqBcETk[hGeA      40.59    -105.08
# 12                               {{vsF~draSv@sGd^?k_B{A      40.10    -105.28
# 13    i{xsFnyqaSmYtBwbEk@k@i}DkFaSsb@{y@iDiKvEqSeAuQ...      40.11    -105.28
# 14    ktfqFdnzaSeBHnNbTjIrCvNwBjKsP`EWhFsEzFrIpIa@v@...      39.69    -105.33
# 15    _fksFx{naSiC|DnDqGFiQzKQm@uHzAgAbWiB`AoE|DkAlA...      40.04    -105.27
# 16    wisvFnzv`SQvG|MwBzO_`ArmB?fpAoi@be@SrDbj@ja@rI...      40.57    -105.14
# 17    ooieFztipSwe@hP~AjLaUjVrWpf@mZ`OtNzXbArf@}s@mh...      37.74    -107.70
# 18    a}{rFnxz`S{z@wAuZdNqp@AqTeIjAboHq`Cs@yo@vDHbfB...      39.96    -105.16
# 19    qjjlFnx{kSpD|@wBjEb@pDvG\n@hB_BdIiFlJcBlMBjMeJ...      38.89    -106.97
# 20    alisFlygaSgDvD|@vNqFi\iBk@QrCq@a@bBzHIgL^`Ai@j...      40.03    -105.23
# 21    ea~uF~zyjSGxD|IzOtAxObDtEzAnIjCnA\nNjCnHaAjQhA...      40.46    -106.80
# 22    qjgrFxud`S?oEnHkA`BiTbD{EdEiRpOhGlGtHrZiXnDsHb...      39.86    -105.05
# 23    cijqFbmnaSwRjFoD|CuCjNzDpPqDzDqDScAmLz@aG}AsNh...      39.71    -105.26
# 24    eleqFhtv_SHpXxk@DHpy@nk@RzUjF\hM~SV|Bth@zI[`Wn...      39.68    -104.98
# 25    mhhqFvhm_Sf@mDp@tJjk@c@M{x@{f@eAfc@maAjk@{gAt[...      39.70    -104.93
# 26    efuqFxad_SNni@lPnA|o@o@b^oc@jdBNpSvOtXiStg@rhA...      39.77    -104.88
# 27    ef`sF|`iaSiHgCsDnAOrE_JtAgfA~yBaBtM_fAgF}EdHXh...      39.98    -105.24
# 28    iu~rFfbk`SCzBiAGVaKvBuBxH`RbGl@qA|fGyPhDgeAKm@...      39.98    -105.08
# 29    k|hqF`{v_Sk@mg@}oBuEyIta@{u@tjAekAhx@am@dN}c@n...      39.70    -104.98
# ...                                                 ...        ...        ...
# 1951  mrbvFpmakSl[ko@rJmH`kBsGvYiMqFzLtS|X|x@uG~_@{K...      40.49    -106.84
# 1952  y`osF|{qaSg`@YoAeA~@qDkRzKag@vJyf@wN{mLCwMqGoc...      40.06    -105.28
# 1953  clmvFdam`SaApC_GJoAGe@wD{IH@jQdcWvBnEa@BeXtEE{...      40.54    -105.09
# 1954  {}sqFdyx_SDrAwBdA`QpWmZra@iOx_@xJfPmLrQmsB^e@r...      39.76    -104.99
# 1955  awwqFjgc`Sd_AlDCdmDvUn@vEpmRmEvw@i]|]pX|uCvr@`...      39.78    -105.04
# 1956  {z`xFtc|kSqB`BhApC_Dd@mFlPaH`DoBuBmGuJ_CyKjA_i...      40.81    -106.97
# 1957  scgsFnvpaScEbE~Gdj@{L`Fj@xmAkB_f@g|B]{ArS_HjJB...      40.02    -105.28
# 1958  }qhqFd~v_SAtMrB^rgFNv@}pDbBuJwDchA`z@I_@jd@lGz...      39.70    -104.98
# 1959  {mopFl`y~RwJVaM}CmAaJeH{AeK|@aByGcSL_OtIaPa@uR...      39.57    -104.83
# 1960  ykhsF|vmaSzX||BfEYhAdFtDc@fBdMrBBqQnDe@fg@e|B[...      40.03    -105.25
# 1961  qhjsF~okaSq@mBkQKm@kYwCaH{EuDA}dCecAe@\auAtg@Z...      40.03    -105.25
# 1962  glhqFz|v_SExPdfFDjCvzBzp@ha@fDsB`Rle@h|@nMvT~M...      39.70    -104.98
# 1963  mdjpFr`v_Sv@|LgFlNoPkAcQh}@u@lf@wf@[cH~OpH|ZOf...      39.54    -104.98
# 1964  mnnqF|vk_Slg@?lDuBr~AJpI_C`h@DdDp@A`BvGkFfDaHi...      39.73    -104.92
# 1965  {nxpFlqf_SmB}DXyEqBuJyQmC^yVyB{IiFuDmNk@Ycx@uu...      39.62    -104.90
# 1966  i~|rFjh{`SaAdDqGl@SvDkBdC}FcH_C}GkIcI_L|Fmr@Fs...      39.97    -105.17
# 1967  ykpsFjdraSv|A}yC{Fl@pFW[pGupA~|Bi|@fZyg@aOcoLS...      40.07    -105.28
# 1968  _u|sF|etaShAbJ{VaZd@hFsAlKgMxQuStK{GS{GdHuGgEa...      40.13    -105.29
# 1969  i`ypFx{u`SBhFI_FnL_@ZkInGYjAdScC`a@h@nKf`@|@Hn...      39.62    -105.14
# 1970  _xfsFn`gaSlAxBUdEyFTx@|I}@d@[rTkAtG{CVy@vD~D`P...      40.02    -105.23
# 1971  wnnkFl}nfSxBuQmFoHyCi@}G~LbCnGxCy@ShCcDx@|DAyC...      38.75    -106.09
# 1972  c_gtFx{heSpd@`p@jOpHd|@uQza@qi@~g@iMzq@`Mx_@|a...      40.18    -105.89
# 1973  gxsqFbx|_SfJK|DlKBkC{GcKlAcBy@kBfEsBd\ud@vJ{E~...      39.76    -105.01
# 1974  sxvnFfxkvSgc@nf@d_@o`@pNyTtC|@FuGjEmHrEdIbHnU}...      39.28    -108.69
# 1975  qdlsFvilaSbCkAQoYkCq@|BqICsH{B{BJ}Dyg@n@Eyq@cH...      40.04    -105.25
# 1976  _kgsFnxoaSvI|nAdbA_LZhM`U?@tMfUZlD|Vco@bUzc@tB...      40.02    -105.27
# 1977  sgirFtviaSb}@yo@`wA`N|XgXtu@}RpYe^|OkDb}@TjtAz...      39.87    -105.24
# 1978  kejsFjosaSvG??zEox@kCwGo_@qSbGd@_]{sBwBku@~Rsg...      40.03    -105.29
# 1979  }_psFhfraSb@~BtK_@@lKqEdMeMZk@tPyZNKk^aBoYmMm@...      40.06    -105.28
# 1980               qlkqFdpn_Sq@jGcIbLTfbAuFzLg@dOeBEWzE      39.71    -104.94
#
# [1981 rows x 7 columns]

# %% [markdown]
# What these are, are simply the geographic locations of every cluster including the index column of the cluster center in the original training set. What this could be useful for is displaying locations on a map to have a user click on and see what routes are leaving from that location. Let's do some simple validation to make sure my clustering is working:

# %%
train[train['activity_id'] == '00c6c4b2']
# Out:
#              id                                        name  distance  \
# 9     131072062               04/16/2014 All I had time for   24710.8
# 11    683147333                                Morning Ride   21759.5
# 214   558630378                                  Lunch Ride   33970.7
# 315   250874039                                  Lunch Ride   30772.6
# 396   735316827  pushing watts....legs feel like lead today   36283.7
# 496   206573176                                 Sunday Ride    7669.4
# 517   358878960                      Lookout Mtn HC warm up    8135.4
# 546   358879149                  Lookout Mtn. Hill Climb x2   50293.3
# 614   186126776                                Morning Ride   23122.4
# 723   468981020                                Morning Ride   27410.5
# 854   143923361                                Morning Ride   30817.5
# 873   325409164                                Morning Ride   45474.8
# 995   341137937                       Lookout x2 in the fog   35853.5
# 1056  175382043                         Chimney - Apex Loop   19788.0
# 1140  327950460                                Morning Ride   15477.0
# 1189  617357893                                Morning Ride   16258.6
# 1465  810560192                                    2x20 min   40978.1
# 1712  155726332                06/19/2014 Lookout Intervals   32640.3
# 1725  330128829                                Morning Ride   15980.2
# 1811  177485028                                     Lookout   18802.1
# 1820  177485075                                     Lookout   36764.1
# 2098  115883026                              Afternoon Ride   35106.0
# 2155  650919349         First mountain climb ever with Josh   15840.8
# 2181  595287996                                Morning Ride   51342.4
# 2192  777273064                                Morning Ride   38775.5
# 2241  112244081                                Morning Ride   33662.6
# 2298  528552704                              Afternoon Ride   15154.2
# 2402  848577898                                Morning Ride   25089.2
# 2543  655378731                                Morning Ride   37408.7
# 2546  313018678             Race pace coach Michael and Ike   31845.4
# 2586  762595930                   November Sunrise on my SS   25754.5
# 2714  403459587                                Morning Ride   22567.8
# 2893  151540550                                         LOs   40271.4
# 3138  109842238                              Afternoon Ride   49430.9
# 3190  641752378                                Morning Ride   31396.6
# 3382  120087253                              Afternoon Ride   30303.3
# 3545  133195689                       04/22/2014 Golden, CO   31324.5
# 3684  251685863                                  Sunny spin   14206.5
# 3721  268201199                      Lookout TT - 1st Place   30780.7
# 3756  528510491                      Lookout Mtn race (3rd)   49599.7
# 3766  186150519                       08/27/2014 Golden, CO   22175.9
# 3774  241462942                                  Lunch Ride   30074.0
# 3804  141848483                           Morning Intervals   20870.1
# 3841  655388841                                Morning Ride   35828.6
# 4094  670071065                                Morning Ride   29768.8
# 4143  110918259                                     Lookout   28619.3
# 4163  118800171                       03/08/2014 Golden, CO   22717.3
#
#       moving_time  elapsed_time  total_elevation_gain  type  \
# 9          3292.0        3292.0                 676.0  Ride
# 11         4400.0        4473.0                 547.0  Ride
# 214        5066.0        5553.0                 912.0  Ride
# 315        4966.0        5345.0                 896.2  Ride
# 396        6170.0        6372.0                 917.0  Ride
# 496        2861.0        3832.0                 347.1  Ride
# 517        1529.0        1886.0                 222.0  Ride
# 546        7218.0       10139.0                1049.0  Ride
# 614        3806.0        4152.0                 677.5  Ride
# 723        4123.0        4407.0                 787.0  Ride
# 854        3879.0        4208.0                 758.4  Ride
# 873        6035.0        6263.0                1238.9  Ride
# 995        5822.0        5874.0                 925.1  Ride
# 1056       5977.0        6283.0                 701.9  Ride
# 1140       2330.0        3599.0                 423.6  Ride
# 1189       2027.0        2124.0                 406.7  Ride
# 1465       7936.0        8064.0                1098.0  Ride
# 1712       5415.0        7390.0                 885.0  Ride
# 1725       3337.0        4017.0                 481.2  Ride
# 1811       3171.0        4761.0                 507.0  Ride
# 1820       5077.0        5308.0                 926.0  Ride
# 2098       5455.0        5971.0                 941.2  Ride
# 2155       4453.0        6036.0                 410.0  Ride
# 2181       7467.0        8128.0                1249.5  Ride
# 2192       6431.0        7063.0                 962.7  Ride
# 2241       5185.0        6062.0                 978.7  Ride
# 2298       2107.0        2182.0                 398.0  Ride
# 2402       4349.0        4409.0                 714.3  Ride
# 2543       6366.0        6474.0                 915.0  Ride
# 2546       4860.0        4916.0                 785.0  Ride
# 2586       4109.0        4309.0                 569.5  Ride
# 2714       4222.0        4814.0                 645.0  Ride
# 2893       5708.0        6079.0                 936.0  Ride
# 3138       7612.0        8508.0                1328.5  Ride
# 3190       5423.0        6138.0                 774.5  Ride
# 3382       4323.0        5021.0                 826.3  Ride
# 3545       3897.0        4168.0                 759.0  Ride
# 3684       2700.0        4544.0                 527.9  Ride
# 3721       4442.0        6138.0                 635.0  Ride
# 3756       7420.0       13340.0                1302.0  Ride
# 3766       3757.0        3858.0                 611.0  Ride
# 3774       4376.0        4804.0                 826.7  Ride
# 3804       3791.0        4348.0                 550.0  Ride
# 3841       5295.0        5816.0                 889.0  Ride
# 4094       5464.0        6106.0                 850.4  Ride
# 4143       5082.0        5596.0                 820.0  Ride
# 4163       4249.0        5096.0                 611.0  Ride
#
#               start_date    start_date_local        timezone     ...      \
# 9    2014-04-16 23:52:21 2014-04-16 17:52:21  America/Denver     ...
# 11   2016-08-18 13:15:13 2016-08-18 07:15:13  America/Denver     ...
# 214  2016-04-27 17:49:19 2016-04-27 11:49:19  America/Denver     ...
# 315  2015-02-05 19:58:14 2015-02-05 12:58:14  America/Denver     ...
# 396  2016-10-05 14:32:30 2016-10-05 08:32:30  America/Denver     ...
# 496  2014-10-12 16:23:19 2014-10-12 10:23:19  America/Denver     ...
# 517  2015-08-01 13:23:53 2015-08-01 07:23:53  America/Denver     ...
# 546  2015-08-01 13:59:59 2015-08-01 07:59:59  America/Denver     ...
# 614  2014-08-27 16:27:15 2014-08-27 10:27:15  America/Denver     ...
# 723  2016-01-12 17:46:13 2016-01-12 10:46:13  America/Denver     ...
# 854  2014-05-21 15:42:36 2014-05-21 09:42:36  America/Denver     ...
# 873  2015-06-14 15:01:16 2015-06-14 09:01:16  America/Denver     ...
# 995  2015-07-07 17:27:19 2015-07-07 11:27:19  America/Denver     ...
# 1056 2014-08-03 21:46:41 2014-08-03 15:46:41  America/Denver     ...
# 1140 2015-06-18 12:34:05 2015-06-18 06:34:05  America/Denver     ...
# 1189 2016-06-22 16:26:06 2016-06-22 10:26:06  America/Denver     ...
# 1465 2016-12-24 16:39:34 2016-12-24 09:39:34  America/Denver     ...
# 1712 2014-06-19 23:45:03 2014-06-19 17:45:03  America/Denver     ...
# 1725 2015-06-21 15:49:29 2015-06-21 09:49:29  America/Denver     ...
# 1811 2014-08-07 22:19:14 2014-08-07 16:19:14  America/Denver     ...
# 1820 2014-08-08 22:16:49 2014-08-08 16:16:49  America/Denver     ...
# 2098 2014-02-24 20:51:51 2014-02-24 13:51:51  America/Denver     ...
# 2155 2016-07-23 16:13:11 2016-07-23 10:13:11  America/Denver     ...
# 2181 2016-06-01 15:55:05 2016-06-01 09:55:05  America/Denver     ...
# 2192 2016-11-16 16:01:37 2016-11-16 09:01:37  America/Denver     ...
# 2241 2014-02-09 17:30:55 2014-02-09 10:30:55  America/Denver     ...
# 2298 2016-03-27 19:42:02 2016-03-27 13:42:02  America/Denver     ...
# 2402 2017-01-29 16:34:47 2017-01-29 09:34:47  America/Denver     ...
# 2543 2016-07-27 13:09:15 2016-07-27 07:09:15  America/Denver     ...
# 2546 2015-05-27 16:38:19 2015-05-27 10:38:19  America/Denver     ...
# 2586 2016-11-01 12:39:27 2016-11-01 06:39:27  America/Denver     ...
# 2714 2015-09-30 13:51:17 2015-09-30 07:51:17  America/Denver     ...
# 2893 2014-06-09 16:09:21 2014-06-09 10:09:21  America/Denver     ...
# 3138 2014-01-29 20:19:47 2014-01-29 13:19:47  America/Denver     ...
# 3190 2016-07-15 13:33:05 2016-07-15 07:33:05  America/Denver     ...
# 3382 2014-03-12 19:05:36 2014-03-12 13:05:36  America/Denver     ...
# 3545 2014-04-22 16:04:22 2014-04-22 10:04:22  America/Denver     ...
# 3684 2015-02-07 18:54:28 2015-02-07 11:54:28  America/Denver     ...
# 3721 2015-03-14 12:47:27 2015-03-14 06:47:27  America/Denver     ...
# 3756 2016-03-27 17:06:23 2016-03-27 11:06:23  America/Denver     ...
# 3766 2014-08-27 16:31:50 2014-08-27 10:31:50  America/Denver     ...
# 3774 2015-01-15 18:10:14 2015-01-15 11:10:14  America/Denver     ...
# 3804 2014-05-16 12:54:21 2014-05-16 06:54:21  America/Denver     ...
# 3841 2016-07-27 14:01:39 2016-07-27 08:01:39  America/Denver     ...
# 4094 2016-08-09 13:05:58 2016-08-09 07:05:58  America/Denver     ...
# 4143 2014-02-02 18:06:47 2014-02-02 11:06:47  America/Denver     ...
# 4163 2014-03-08 17:49:39 2014-03-08 10:49:39  America/Denver     ...
#
#       athlete_id      map_id  \
# 9         373166  a131072062
# 11       9428936  a683147333
# 214      1514935  a558630378
# 315      1412833  a250874039
# 396      1183267  a735316827
# 496      1411091  a206573176
# 517        55375  a358878960
# 546        55375  a358879149
# 614      1412833  a186126776
# 723      1514935  a468981020
# 854      1412833  a143923361
# 873      1412833  a325409164
# 995      4404581  a341137937
# 1056     1411091  a175382043
# 1140      624147  a327950460
# 1189     1412833  a617357893
# 1465     1183267  a810560192
# 1712     2785417  a155726332
# 1725     1412833  a330128829
# 1811     1514935  a177485028
# 1820     1514935  a177485075
# 2098     1412833  a115883026
# 2155    10478514  a650919349
# 2181     1412833  a595287996
# 2192     1412833  a777273064
# 2241     1412833  a112244081
# 2298     1514935  a528552704
# 2402     1412833  a848577898
# 2543     1183267  a655378731
# 2546     1183267  a313018678
# 2586     7360660  a762595930
# 2714     1412833  a403459587
# 2893     2179260  a151540550
# 3138     1412833  a109842238
# 3190     1412833  a641752378
# 3382     1412833  a120087253
# 3545     1412833  a133195689
# 3684     2584485  a251685863
# 3721      468938  a268201199
# 3756      373166  a528510491
# 3766     1183267  a186150519
# 3774     1412833  a241462942
# 3804     1183267  a141848483
# 3841     1514935  a655388841
# 4094     1412833  a670071065
# 4143     1514935  a110918259
# 4163     1183267  a118800171
#
#                                    map_summary_polyline  start_lat  start_lng  \
# 9     oaqqFfjgaSjJuAiBzHf@nG{BzAyBtGaGzEFnGcHy@_AdBR...      39.74    -105.23
# 11    {aqqFljgaSKfA~JsCeBhHh@hG}N`RHrGmH_Ao@jBd@bFkH...      39.74    -105.23
# 214   e_qqFtkgaS`HcCw@tP}NhRFbGuGcAw@fJaGu@gIzHtIsHv...      39.74    -105.23
# 315   e`qqFvigaSmAdAzJqCi@bQuNnQDvGkH_Ae@hJ{FcAwUvSn...      39.74    -105.23
# 396   maqqFzigaSbJgAq@dPmOzStOmSb@eQiMlEjM_EsAfK|AmK...      39.74    -105.23
# 496   kwrqFnqgaSlBfKnEx@f@bGs@zBdOeA~FvCjAuAxJ`FTzAb...      39.75    -105.23
# 517   acqqFflgaS_BP}KwQ{L|LAnN|OxP|Bb@~RaOa@oH`BuHyN...      39.74    -105.23
# 546   iypqFfigaSf@rOuN~Y_H}@i@~Ig[xL`@bf@dGsKiAaPrb@...      39.74    -105.23
# 614   {bqqFligaSlACa@zA|JaDsA`FpAmFoDtAdDu@uBvIj@pFk...      39.74    -105.23
# 723   _bqqFfjgaSzJ{AgB`If@nGuNlQ@lGcIUFfGE_GjIJM_G|N...      39.74    -105.23
# 854   _`qqFdjgaSgDxAiFqH{d@gcAy{AptAkRnUu@pKgR`FkOqD...      39.74    -105.23
# 873   _aqqF|jgaSzImBg@lPuNhZaHy@m@zIgGk@oUpSbBfa@pGg...      39.74    -105.23
# 995   mbqqFhhgaS~JUw@`QsNrQ?rG{G_Aq@dJ{F{@cSpNwAvEnD...      39.74    -105.23
# 1056  kvrqFzpgaSlA~K|E|@WzJpNmAvFjAJrAxA}AnKfIfDFmE~...      39.75    -105.23
# 1140  _bqqFrigaSIhAbA?tHsC_BfIr@fFiOtRFhGiGgAmAtC@dF...      39.74    -105.23
# 1189  cbqqFxigaSh@nAfJaDgBpHj@jGeOnRNtFaH{@{@xALbGcG...      39.74    -105.23
# 1465  obqqFnhgaSdKc@{@jQsNlQYvGmHa@G~HuFcAsJjLuG|@_B...      39.74    -105.23
# 1712  caqqF|igaStIgAs@bQyNnQHrGcJZhJKEmH`OcRZcQ{BnA`...      39.74    -105.23
# 1725  maqqFvjgaSnJ}AiBnHb@bHcO~Qn@zF|Dd@{ACiCtEjDsAh...      39.74    -105.23
# 1811  _bqqFzjgaSzJgBcB`Id@bGmNfQ@pGgHu@c@`J}F{@eHfEk...      39.74    -105.23
# 1820  cbqqFvjgaS|JiBq@jP}NrR`OuQ|@kQkDdA|Cw@y@zP{NhR...      39.74    -105.23
# 2098  uaqqFnjgaSlJaB{@zPmOfRLdG}GaAg@hJ{Gu@wTfSjD|P_...      39.74    -105.23
# 2155  ibqqFphgaSZzBxImCyA`Hb@hHuNlQ?jGcIMBvHeG{@{GtD...      39.74    -105.23
# 2181  w`qqFnjgaSxIsAaAnPaNlYpNqYz@oQyMfFbMsE_@lP}NvZ...      39.74    -105.23
# 2192  _aqqFvigaStImAy@dQwOfS`@lFiH_Ai@pJqG_AkUzS|DtP...      39.74    -105.23
# 2241  _`qqFbhgaS~HS{@nPsNnZkHg@SfJwG{@oUrSvBb`@bGoKo...      39.74    -105.23
# 2298  aypqF|hgaSxA[aBjHf@|FwNfRBbG{Gu@_AhBRvFgGy@aH`...      39.74    -105.23
# 2402  w`qqFljgaSo@p@zJwCgBzHl@zFcOnRPhGoHy@{@dBPfG}E...      39.74    -105.23
# 2543  _aqqFvhgaSvI]q@hP_OdRFjGkHq@c@zIoGq@cUfSbD~Pu@...      39.74    -105.23
# 2546  kbqqFdjgaS~JkAu@zP{NdRJxF{Gy@}@fJ{Fw@gUhSfDtPa...      39.74    -105.23
# 2586  ubqqFpggaSZpClJuC_BdIh@hGyNnQ?tGuGmAcA`BJtG{Fe...      39.74    -105.23
# 2714  waqqFfhgaS?lCpJgD_BtIn@dFeOvRFfGoH{@u@zAVdGsGw...      39.74    -105.23
# 2893  sbqqFbhgaS~J[u@pQwNjQ@fGmIA@rH}F}@iSvNuAnEpD|N...      39.74    -105.23
# 3138  gaqqFrjgaSeT_XxOb[rNgEg@bQ{Yzc@c[bLf@be@rDk\tb...      39.74    -105.23
# 3190  }aqqF`igaS|Js@u@fQuNjQpNeQdAaRyM`FxMaFuA|FtA}F...      39.74    -105.23
# 3382  eaqqFbjgaSzIoAs@pPsNxQ?lGwHk@i@bJeFgAoUpSfDxQc...      39.74    -105.23
# 3545  kaqqFrggaS\bEpIwBRlOcS~VsEBaCjGqYxP}@jFdF`[hDO...      39.74    -105.23
# 3684  }aqqFfigaSFbBhJ_DoBrH|@`GkOvR^zF{Hk@u@xAd@zFeH...      39.74    -105.23
# 3721  gbqqFnhgaSIlBaBb@_GiJ`H_DcIbB_j@ulAw]fZyCcIiMw...      39.74    -105.23
# 3756  y~pqFhkgaSnGsBw@xPwNfZ}G{@o@bJaG}@kUzShBv`@lGe...      39.74    -105.23
# 3766  ebqqFpjgaStJuAcBvHh@dGyNvQLzF}Gs@eA~APfGyFaAiH...      39.74    -105.23
# 3774  }`qqF`jgaSfI{@o@xPcO~QNpFsHi@U~IcGcAqUvSfDtP}@...      39.74    -105.23
# 3804  mbqqFpjgaSnJqBaL|DjLsD{AbIr@hF}NlR@lGaHy@}@`BP...      39.74    -105.23
# 3841  abqqFfigaSvJw@s@pP_OrRLzF}Gw@s@bJcGq@qUlSfCvVu...      39.74    -105.23
# 4094  caqqFdjgaSzI_Bw@~PeOjRNfGgHy@e@dJsGw@cUvS^lEhA...      39.74    -105.23
# 4143  {|pqFrjgaSzEwB{@vQgOnZwG{@g@rIwGg@{T~RvBja@bGc...      39.74    -105.23
# 4163  ibqqFjlgaS|J}CcBzHL~GoNpQFvFwGs@g@zIcGq@_HxDaA...      39.74    -105.23
#
#       end_lat end_lng     state closest_city activity_id
# 9       39.74 -105.23  Colorado       Golden    00c6c4b2
# 11      39.74 -105.23  Colorado       Golden    00c6c4b2
# 214     39.74 -105.23  Colorado       Golden    00c6c4b2
# 315     39.74 -105.23  Colorado       Golden    00c6c4b2
# 396     39.74 -105.23  Colorado       Golden    00c6c4b2
# 496     39.75 -105.23  Colorado       Golden    00c6c4b2
# 517     39.74 -105.23  Colorado       Golden    00c6c4b2
# 546     39.74 -105.23  Colorado       Golden    00c6c4b2
# 614     39.74 -105.23  Colorado       Golden    00c6c4b2
# 723     39.74 -105.23  Colorado       Golden    00c6c4b2
# 854     39.74 -105.23  Colorado       Golden    00c6c4b2
# 873     39.74 -105.23  Colorado       Golden    00c6c4b2
# 995     39.74 -105.23  Colorado       Golden    00c6c4b2
# 1056    39.75 -105.23  Colorado       Golden    00c6c4b2
# 1140    39.74 -105.23  Colorado       Golden    00c6c4b2
# 1189    39.74 -105.23  Colorado       Golden    00c6c4b2
# 1465    39.74 -105.23  Colorado       Golden    00c6c4b2
# 1712    39.74 -105.23  Colorado       Golden    00c6c4b2
# 1725    39.74 -105.23  Colorado       Golden    00c6c4b2
# 1811    39.74 -105.23  Colorado       Golden    00c6c4b2
# 1820    39.74 -105.23  Colorado       Golden    00c6c4b2
# 2098    39.74 -105.23  Colorado       Golden    00c6c4b2
# 2155    39.74 -105.23  Colorado       Golden    00c6c4b2
# 2181    39.74 -105.23  Colorado       Golden    00c6c4b2
# 2192    39.74 -105.23  Colorado       Golden    00c6c4b2
# 2241    39.74 -105.23  Colorado       Golden    00c6c4b2
# 2298    39.74 -105.23  Colorado       Golden    00c6c4b2
# 2402    39.74 -105.23  Colorado       Golden    00c6c4b2
# 2543    39.74 -105.23  Colorado       Golden    00c6c4b2
# 2546    39.74 -105.23  Colorado       Golden    00c6c4b2
# 2586    39.74 -105.23  Colorado       Golden    00c6c4b2
# 2714    39.74 -105.23  Colorado       Golden    00c6c4b2
# 2893    39.74 -105.23  Colorado       Golden    00c6c4b2
# 3138    39.74 -105.23  Colorado       Golden    00c6c4b2
# 3190    39.74 -105.23  Colorado       Golden    00c6c4b2
# 3382    39.74 -105.23  Colorado       Golden    00c6c4b2
# 3545    39.74 -105.23  Colorado       Golden    00c6c4b2
# 3684    39.74 -105.23  Colorado       Golden    00c6c4b2
# 3721    39.74 -105.23  Colorado       Golden    00c6c4b2
# 3756    39.74 -105.23  Colorado       Golden    00c6c4b2
# 3766    39.74 -105.23  Colorado       Golden    00c6c4b2
# 3774    39.74 -105.23  Colorado       Golden    00c6c4b2
# 3804    39.74 -105.23  Colorado       Golden    00c6c4b2
# 3841    39.74 -105.23  Colorado       Golden    00c6c4b2
# 4094    39.74 -105.23  Colorado       Golden    00c6c4b2
# 4143    39.74 -105.23  Colorado       Golden    00c6c4b2
# 4163    39.74 -105.23  Colorado       Golden    00c6c4b2
#
# [47 rows x 41 columns]

# %%
test['activity_id'] = test_labels

# %%
test[test['activity_id'] == '00c6c4b2']
# Out:
#              id                          name  distance  moving_time  \
# 103   358877240                       Lookout   20247.3       2608.0
# 169   226496048             1x28min. interval   24861.9       4004.0
# 268   611063717                  Morning Ride   31493.6       4397.0
# 285   687927172                Afternoon Ride   29389.2       4715.0
# 498   867708346  Wednesday Hill Climber Group   51426.4       8524.0
# 526   837562539                    Lunch Ride   36615.7       5498.0
# 556   551563980    Intervals w/M....heavy air   28490.3       5064.0
# 662   226245556                       Lookout   31361.1       4455.0
# 681   412892571                  Morning Ride   23793.4       3377.0
# 712   183517092                Afternoon Ride   34389.8       4209.0
# 936   128820743                  Morning Ride   43342.9       5928.0
# 969   787571699                    Lunch Ride   19354.5       3373.0
# 1076  138960917                    Lunch Ride   25924.2       3437.0
# 1117  659841585                  Morning Ride   24848.0       4517.0
# 1187  250898727                       Lookout   30315.5       4801.0
# 1195  143157675                  Morning Ride   77022.5      10973.0
# 1196  270297541                     1x15/2x12   23847.7       4242.0
# 1255  404778821                  Morning Ride   32717.5       4633.0
# 1386  599554798                  Morning Ride   34538.9       4714.0
#
#       elapsed_time  total_elevation_gain  type          start_date  \
# 103         3307.0                 476.0  Ride 2015-08-01 15:45:06
# 169         4125.0                 610.0  Ride 2014-12-05 18:24:56
# 268         4962.0                 834.8  Ride 2016-06-16 13:15:55
# 285         4922.0                 805.0  Ride 2016-08-24 19:37:44
# 498        10098.0                1359.0  Ride 2017-02-15 17:11:53
# 526         5563.0                1028.0  Ride 2017-01-19 19:43:46
# 556         5396.0                 749.0  Ride 2016-04-20 15:58:04
# 662         4797.0                 844.4  Ride 2014-12-04 19:00:31
# 681         3648.0                 608.8  Ride 2015-10-14 13:23:35
# 712         4480.0                 861.2  Ride 2014-08-21 19:32:15
# 936         6486.0                1199.8  Ride 2014-04-10 15:19:10
# 969         3620.0                 650.0  Ride 2016-11-27 19:29:36
# 1076        3938.0                 611.3  Ride 2014-05-08 18:44:49
# 1117        5565.0                 674.5  Ride 2016-07-31 15:33:52
# 1187        5169.0                 813.0  Ride 2015-02-05 20:00:30
# 1195       12190.0                1875.6  Ride 2014-05-19 15:23:32
# 1196        4441.0                 660.0  Ride 2015-03-18 16:11:27
# 1255        4885.0                 822.0  Ride 2015-09-29 13:25:18
# 1386        5427.0                 862.3  Ride 2016-06-05 14:55:30
#
#         start_date_local        timezone     ...      athlete_id      map_id  \
# 103  2015-08-01 09:45:06  America/Denver     ...         2961139  a358877240
# 169  2014-12-05 11:24:56  America/Denver     ...         1183267  a226496048
# 268  2016-06-16 07:15:55  America/Denver     ...         1412833  a611063717
# 285  2016-08-24 13:37:44  America/Denver     ...         1514935  a687927172
# 498  2017-02-15 10:11:53  America/Denver     ...         2638390  a867708346
# 526  2017-01-19 12:43:46  America/Denver     ...         1514935  a837562539
# 556  2016-04-20 09:58:04  America/Denver     ...         1183267  a551563980
# 662  2014-12-04 12:00:31  America/Denver     ...         1514935  a226245556
# 681  2015-10-14 07:23:35  America/Denver     ...         1412833  a412892571
# 712  2014-08-21 13:32:15  America/Denver     ...         1412833  a183517092
# 936  2014-04-10 09:19:10  America/Denver     ...         1412833  a128820743
# 969  2016-11-27 12:29:36  America/Denver     ...         1514935  a787571699
# 1076 2014-05-08 12:44:49  America/Denver     ...         1412833  a138960917
# 1117 2016-07-31 09:33:52  America/Denver     ...         1412833  a659841585
# 1187 2015-02-05 13:00:30  America/Denver     ...         1514935  a250898727
# 1195 2014-05-19 09:23:32  America/Denver     ...         1412833  a143157675
# 1196 2015-03-18 10:11:27  America/Denver     ...         1183267  a270297541
# 1255 2015-09-29 07:25:18  America/Denver     ...         1412833  a404778821
# 1386 2016-06-05 08:55:30  America/Denver     ...         1412833  a599554798
#
#                                    map_summary_polyline  start_lat  start_lng  \
# 103   aypqFxhgaSnAc@eB|Hl@tFoN|QDtGmHw@e@|IgGu@{GzDi...      39.74    -105.23
# 169   qbqqFnjgaSzJ{AyAvHn@pFaOpRHbGiGcAuAlDdBaDrFhAJ...      39.74    -105.23
# 268   s`qqFfjgaStIkAgB|RpBmSqAhRuGnJpHmLr@aQy@tQeOlR...      39.74    -105.23
# 285   w`qqF|igaSq@x@bKgCcB`In@dFgOrRJ|FgHo@i@~IsF}@m...      39.74    -105.23
# 498   gaqqFhlgaS~IqCw@`QyNrQHdGiHs@e@bJwGo@_UpSlD|Py...      39.74    -105.23
# 526   caqqFfjgaS|IwAw@nP_OnRL|FeHq@o@bJqGo@_UlShDbQ}...      39.74    -105.23
# 556   _bqqFrigaSpJ}@o@xPsNxPClHgHs@c@`JyOrBcMxOlDbOk...      39.74    -105.23
# 662   {bqqF~ggaSb@tClJ{DqMjEgDqD|CfE|MsE{@xQ{NhQDnG}...      39.74    -105.23
# 681   q`qqFfhgaSeDrC{NkWbOtXbNuE}AbIf@zFqNvQM|GoGcAc...      39.74    -105.23
# 712   _bqqFdkgaS}C?oQuZwZnXsEb`@uFlJsFbE_Lp@mIyFs\yI...      39.74    -105.23
# 936   cbqqFbigaSrJq@c@`QsNzYkGkA}@dJc[`MRpe@fG{JmAiP...      39.74    -105.23
# 969   saqqFxhgaSHrB|IeDaBfIn@|E}NzRFdGcHw@{@~AP~FyGi...      39.74    -105.23
# 1076  maqqF|igaS_@x@|JoC{AvHl@fGcDbCfDoB_@yGdBgIwOtD...      39.74    -105.23
# 1117  uaqqFnjgaSpJiBiBjIj@fG}NrQHrGiI_@F|HL{HpH\DkHt...      39.74    -105.23
# 1187  saqqFfjgaShJ{Am@tP_OlRJ`GiHs@e@~I}Gi@qT|RbDdQw...      39.74    -105.23
# 1195  waqqF`kgaSmKcIuc@i`AyyArrAoT~We@|Jub@VgGxk@lCj...      39.74    -105.23
# 1196  kbqqFvjgaS~JaBaBlHh@pGaO~QPtFkHk@w@~APxFqGm@sG...      39.74    -105.23
# 1255  ibqqFvigaSfK{@}@xPuNtQ?hG}Gq@m@~IsGk@}TlShDlQ_...      39.74    -105.23
# 1386  qbqqFdhgaSfKKw@lQeO`RF|FcIc@@jI{FcAuSzNsAjEjDx...      39.74    -105.23
#
#       end_lat end_lng     state closest_city activity_id
# 103     39.74 -105.23  Colorado       Golden    00c6c4b2
# 169     39.74 -105.23  Colorado       Golden    00c6c4b2
# 268     39.74 -105.23  Colorado       Golden    00c6c4b2
# 285     39.74 -105.23  Colorado       Golden    00c6c4b2
# 498     39.74 -105.23  Colorado       Golden    00c6c4b2
# 526     39.74 -105.23  Colorado       Golden    00c6c4b2
# 556     39.74 -105.23  Colorado       Golden    00c6c4b2
# 662     39.74 -105.23  Colorado       Golden    00c6c4b2
# 681     39.74 -105.23  Colorado       Golden    00c6c4b2
# 712     39.74 -105.23  Colorado       Golden    00c6c4b2
# 936     39.74 -105.23  Colorado       Golden    00c6c4b2
# 969     39.74 -105.23  Colorado       Golden    00c6c4b2
# 1076    39.74 -105.23  Colorado       Golden    00c6c4b2
# 1117    39.74 -105.23  Colorado       Golden    00c6c4b2
# 1187    39.74 -105.23  Colorado       Golden    00c6c4b2
# 1195    39.74 -105.23  Colorado       Golden    00c6c4b2
# 1196    39.74 -105.23  Colorado       Golden    00c6c4b2
# 1255    39.74 -105.23  Colorado       Golden    00c6c4b2
# 1386    39.74 -105.23  Colorado       Golden    00c6c4b2
#
# [19 rows x 41 columns]

# %%
from scipy.stats.kde import gaussian_kde

# use activities with id 00c6c4b2
dfa = train[train['activity_id'] == '00c6c4b2']
dfb = test[test['activity_id'] == '00c6c4b2']

train_dsts = dfa['distance'].values
test_dsts = dfb['distance'].values
plt.hist(train_dsts, bins=15, alpha=.1, edgecolor='none', color='g', normed=1)
plt.hist(test_dsts, bins=15, alpha=.1, edgecolor='none', color='b', normed=1)

# Plotting the KDE of train and test
kde_pdf = gaussian_kde(train_dsts)
x = np.linspace(min(train_dsts), max(train_dsts), 1000)
y = kde_pdf(x)
plt.plot(x, y, color='b', lw=2, label='training set distances')

kde_pdf = gaussian_kde(test_dsts)
x = np.linspace(min(test_dsts), max(test_dsts), 1000)
y = kde_pdf(x)
plt.plot(x, y, color='g', lw=2, label='test set distances')
plt.ylabel('Probability Density', fontsize=14)
plt.xlabel('distance (m)', fontsize=14)

plt.legend(frameon=False)
plt.show()

# %% [markdown]
# Compared to training data the test data appears to have a similar distribution in the distances of the rides taken. This is good since it show that most of the activities with the same activity_id are around the same distance traveled by the athlete. Let's take a look at elevation gain:

# %%
train_dsts = dfa['total_elevation_gain'].values
test_dsts = dfb['total_elevation_gain'].values
plt.hist(train_dsts, bins=15, alpha=.1, edgecolor='none', color='g', normed=1)
plt.hist(test_dsts, bins=15, alpha=.1, edgecolor='none', color='b', normed=1)

# Plotting the KDE of train and test
kde_pdf = gaussian_kde(train_dsts)
x = np.linspace(min(train_dsts), max(train_dsts), 1000)
y = kde_pdf(x)
plt.plot(x, y, color='b', lw=2, label='training set elevation gain')

kde_pdf = gaussian_kde(test_dsts)
x = np.linspace(min(test_dsts), max(test_dsts), 1000)
y = kde_pdf(x)
plt.plot(x, y, color='g', lw=2, label='test set elevation gain')
plt.ylabel('Probability Density', fontsize=14)
plt.xlabel('total elevation gain (m)', fontsize=14)

plt.legend(frameon=False)
plt.show()

# %% [markdown]
# ## Ratings
#
# Using this small dataset again, let's see if we can get the ratings for athlete's identified by their id.

# %%
df =
